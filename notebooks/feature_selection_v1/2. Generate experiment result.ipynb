# %% [markdown]
# # Prerequisite
#
# Following packages must be installed to run codes below
#
# ```bash
# $ pip3 install openpyxl
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Add project path

# %%
import os
import sys
from pathlib import Path

PROJECT_PATH = Path().resolve().parent.parent
SRC_PATH = PROJECT_PATH / 'src'

sys.path.append(str(SRC_PATH))

# %%
exp_name = 'feature_seleciton_v1'

# %% [markdown]
# # Load data

# %%
from data_loader import SectorDataLoader

data_loader = SectorDataLoader()
data_finance = (
    data_loader
    .load_dataset()
    .pipe(data_loader.add_beaver_indicator)
    .pipe(data_loader.add_label)
)
data_finance.head()
# Out:
#          BIZ_NO CMP_PFIX_NM   CMP_NM CMP_NM1 CMP_SFIX_NM  \
# 117  1018135422         (주)   한국선박기술     NaN         NaN
# 219  1018154206         (주)     드림미즈     NaN         NaN
# 279  1018163684         NaN  디에프에스서울     NaN         (주)
# 339  1018178760         (주)    대교디앤씨     NaN         NaN
# 406  1018194173         NaN    에코에너지     NaN         (주)
#
#                        CMP_ENM BZ_TYP  CMP_TYP  CMP_SCL  PBCO_GB  ...  \
# 117  Korea Marine Time Service      M      NaN        2        2  ...
# 219         dreammiz Co., Ltd.      M      NaN        2        2  ...
# 279             DFS Seoul Ltd.      M      NaN        2        2  ...
# 339      DAEGYO D & C CO.,LTD.      M      NaN        2        2  ...
# 406        Eco Energy Co.,Ltd.      M      NaN        2        2  ...
#
#      STAT_OCR_DATE_y  Closed_Year  유동자산/부채총계 당기순이익(손실)/자산총계 부채총계/자산총계  \
# 117       20200930.0       2020.0   1.031451       0.038773  0.578094
# 219       20201231.0       2020.0   1.220040       0.001177  0.662356
# 279       20190917.0       2019.0  11.012914       0.046666  0.090794
# 339       20191010.0       2019.0   0.916364      -0.026128  1.091269
# 406       20200831.0       2020.0   1.183355      -0.062095  0.828142
#
#      순운전자본/자산총계  유동부채/유동자산  Years_From_Closed_Year_To_FS  Closed_In_1Yr  \
# 117    0.543045   0.089273                           2.0              0
# 219    0.608449   0.247063                           2.0              0
# 279    0.909114   0.090802                           1.0              1
# 339    0.097514   0.902486                           1.0              1
# 406    0.194625   0.801400                           2.0              0
#
#      Closed_In_2Yrs
# 117               1
# 219               1
# 279               1
# 339               1
# 406               1
#
# [5 rows x 104 columns]

# %%
data = data_finance

# %% [markdown]
# # Baseline classifier using Beaver's features

# %%
from project_paths import DATA_PATH

sectors = [
    '제조업(10~34)',
    '부동산업(68)',
    '도매 및 소매업(45~47)',
    '숙박 및 음식점업(55~56)',
    '건설업(41~42)'
]

beaver_features = [
    '유동자산/부채총계',
    '당기순이익(손실)/자산총계',
    '부채총계/자산총계',
    '순운전자본/자산총계',
    '유동부채/유동자산'
]

extended_financial_features = [
    '유동자산',
    '매출채권',
    '비유동자산',
    '유형자산',
    '자산총계',
    '유동부채',
    '비유동부채',
    '부  채  총  계',
    '자본금',
    '이익잉여금(결손금）',
    '자본총계',
    '매출액',
    '판매비와관리비',
    '영업이익（손실）',
    '법인세비용차감전순손익',
    '법인세비용',
    '당기순이익(손실)',
    '기업순이익률(%)',
    '유보액/총자산(%)',
    '유보액/납입자본(%)',
    '매출액총이익률(%)',
    '매출액영업이익률(%)',
    '매출액순이익률(%)',
    '수지비율(%)',
    '경상수지비율',
    '영업비율(%)',
    '금융비용대매출액비율(%',
    '금융비용대부채비율(%)',
    '금융비용대총비용비율(%',
    '부채비율(%)',
    '차입금의존도(%)',
    '자기자본비율(%)',
    '순운전자본비율(%)',
    '유동부채비율(%)',
    '비유동부채비율(%)',
    '부채총계대 매출액(%)',
    '총자본회전율(회)',
    '재고자산회전율(회)',
    '매출채권회전율(회)',
    '매입채무회전율(회)',
    '미수금',
    '매출원가',
    '무형자산',
    '재고자산',
]

years_to_close = [
    'Closed_In_1Yr',
    'Closed_In_2Yrs',
]

x_data_year = list(range(2018, 2021))

EXP_RESULT_PATH = DATA_PATH / 'experiment_result' / exp_name

if not os.path.exists(EXP_RESULT_PATH) : 
    os.mkdir(EXP_RESULT_PATH)

# %%
import numpy as np
import pandas as pd
from pycaret.classification import ClassificationExperiment
from tqdm import tqdm

# %%
exp_result = None

for target_years_to_close in tqdm(years_to_close) : 
    for x_data_target_year in tqdm(x_data_year, leave=True) : 
        for sector in sectors : 

            filename = EXP_RESULT_PATH / f'Beaver_baseline_{sector}_{target_years_to_close}_{x_data_target_year}.csv'

            if not os.path.exists(filename) : 

                data_to_train = (
                    data
                    .loc[~data[beaver_features[0]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[1]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[2]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[3]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[4]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[lambda x : pd.to_datetime(x['결산년월'], format='%Y%m%d').dt.year==x_data_target_year]
                    .loc[lambda x : x['대분류']==sector]
                )

                exp = ClassificationExperiment()

                exp.setup(
                    (
                        data_to_train
                        .loc[:, beaver_features+extended_financial_features+[target_years_to_close]]
                        .reset_index(drop=True)
                    ),
                    target=target_years_to_close
                )

                models = exp.compare_models()

                result = (
                    exp.pull()
                    .assign(target=target_years_to_close)
                    .assign(x_data_yaer=x_data_target_year)
                    .assign(대분류=sector)
                    .reset_index(drop=False)
                    .rename(columns={'index':'model_name'})
                )
                result.to_csv(filename)

            else : 
                result = pd.read_csv(filename)

            if exp_result is None : 
                exp_result = result
            else : 
                exp_result = pd.concat([exp_result, result], axis=0)
# Out:
#   0%|                                                                                    | 0/2 [00:00<?, ?it/s]
#   0%|                                                                                    | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d42db_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d42db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d42db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d42db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d42db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d42db_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d42db_row0_col1" class="data row0 col1" >5814</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d42db_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d42db_row1_col1" class="data row1 col1" >Closed_In_1Yr</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d42db_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d42db_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d42db_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d42db_row3_col1" class="data row3 col1" >(1800, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d42db_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d42db_row4_col1" class="data row4 col1" >(1800, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d42db_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d42db_row5_col1" class="data row5 col1" >(1259, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d42db_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d42db_row6_col1" class="data row6 col1" >(541, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d42db_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d42db_row7_col1" class="data row7 col1" >49</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d42db_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_d42db_row8_col1" class="data row8 col1" >84.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d42db_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d42db_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d42db_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d42db_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d42db_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d42db_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d42db_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d42db_row12_col1" class="data row12 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d42db_row13_col0" class="data row13 col0" >Low variance threshold</td>
#       <td id="T_d42db_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d42db_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_d42db_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d42db_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_d42db_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d42db_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_d42db_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d42db_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_d42db_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d42db_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_d42db_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d42db_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_d42db_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d42db_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d42db_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_d42db_row20_col1" class="data row20 col1" >cc39</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9c73a th {
#   text-align: left;
# }
# #T_9c73a_row0_col0, #T_9c73a_row0_col2, #T_9c73a_row0_col3, #T_9c73a_row0_col5, #T_9c73a_row1_col0, #T_9c73a_row1_col1, #T_9c73a_row1_col2, #T_9c73a_row1_col3, #T_9c73a_row1_col4, #T_9c73a_row1_col5, #T_9c73a_row1_col6, #T_9c73a_row1_col7, #T_9c73a_row2_col0, #T_9c73a_row2_col1, #T_9c73a_row2_col3, #T_9c73a_row2_col4, #T_9c73a_row2_col5, #T_9c73a_row2_col6, #T_9c73a_row2_col7, #T_9c73a_row3_col0, #T_9c73a_row3_col1, #T_9c73a_row3_col2, #T_9c73a_row3_col3, #T_9c73a_row3_col4, #T_9c73a_row3_col5, #T_9c73a_row3_col6, #T_9c73a_row3_col7, #T_9c73a_row4_col0, #T_9c73a_row4_col1, #T_9c73a_row4_col2, #T_9c73a_row4_col3, #T_9c73a_row4_col4, #T_9c73a_row4_col5, #T_9c73a_row4_col6, #T_9c73a_row4_col7, #T_9c73a_row5_col0, #T_9c73a_row5_col1, #T_9c73a_row5_col2, #T_9c73a_row5_col3, #T_9c73a_row5_col4, #T_9c73a_row5_col5, #T_9c73a_row5_col6, #T_9c73a_row5_col7, #T_9c73a_row6_col0, #T_9c73a_row6_col1, #T_9c73a_row6_col2, #T_9c73a_row6_col3, #T_9c73a_row6_col4, #T_9c73a_row6_col5, #T_9c73a_row6_col6, #T_9c73a_row6_col7, #T_9c73a_row7_col0, #T_9c73a_row7_col1, #T_9c73a_row7_col2, #T_9c73a_row7_col3, #T_9c73a_row7_col4, #T_9c73a_row7_col5, #T_9c73a_row7_col6, #T_9c73a_row7_col7, #T_9c73a_row8_col0, #T_9c73a_row8_col1, #T_9c73a_row8_col2, #T_9c73a_row8_col3, #T_9c73a_row8_col4, #T_9c73a_row8_col5, #T_9c73a_row8_col6, #T_9c73a_row8_col7, #T_9c73a_row9_col0, #T_9c73a_row9_col1, #T_9c73a_row9_col2, #T_9c73a_row9_col3, #T_9c73a_row9_col4, #T_9c73a_row9_col5, #T_9c73a_row9_col6, #T_9c73a_row9_col7, #T_9c73a_row10_col0, #T_9c73a_row10_col1, #T_9c73a_row10_col2, #T_9c73a_row10_col3, #T_9c73a_row10_col4, #T_9c73a_row10_col5, #T_9c73a_row10_col6, #T_9c73a_row10_col7, #T_9c73a_row11_col0, #T_9c73a_row11_col1, #T_9c73a_row11_col2, #T_9c73a_row11_col3, #T_9c73a_row11_col4, #T_9c73a_row11_col5, #T_9c73a_row11_col6, #T_9c73a_row11_col7, #T_9c73a_row12_col0, #T_9c73a_row12_col1, #T_9c73a_row12_col2, #T_9c73a_row12_col3, #T_9c73a_row12_col4, #T_9c73a_row12_col5, #T_9c73a_row12_col6, #T_9c73a_row12_col7, #T_9c73a_row13_col0, #T_9c73a_row13_col1, #T_9c73a_row13_col2, #T_9c73a_row13_col4, #T_9c73a_row13_col6, #T_9c73a_row13_col7 {
#   text-align: left;
# }
# #T_9c73a_row0_col1, #T_9c73a_row0_col4, #T_9c73a_row0_col6, #T_9c73a_row0_col7, #T_9c73a_row2_col2, #T_9c73a_row13_col3, #T_9c73a_row13_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9c73a_row0_col8, #T_9c73a_row1_col8, #T_9c73a_row2_col8, #T_9c73a_row3_col8, #T_9c73a_row4_col8, #T_9c73a_row5_col8, #T_9c73a_row6_col8, #T_9c73a_row8_col8, #T_9c73a_row9_col8, #T_9c73a_row10_col8, #T_9c73a_row11_col8, #T_9c73a_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9c73a_row7_col8, #T_9c73a_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9c73a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c73a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9c73a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9c73a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9c73a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9c73a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9c73a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9c73a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9c73a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9c73a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c73a_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_9c73a_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_9c73a_row0_col1" class="data row0 col1" >0.8769</td>
#       <td id="T_9c73a_row0_col2" class="data row0 col2" >0.6900</td>
#       <td id="T_9c73a_row0_col3" class="data row0 col3" >0.1349</td>
#       <td id="T_9c73a_row0_col4" class="data row0 col4" >0.6762</td>
#       <td id="T_9c73a_row0_col5" class="data row0 col5" >0.2162</td>
#       <td id="T_9c73a_row0_col6" class="data row0 col6" >0.1810</td>
#       <td id="T_9c73a_row0_col7" class="data row0 col7" >0.2532</td>
#       <td id="T_9c73a_row0_col8" class="data row0 col8" >0.1190</td>
#     </tr>
#     <tr>
#       <th id="T_9c73a_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_9c73a_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_9c73a_row1_col1" class="data row1 col1" >0.8745</td>
#       <td id="T_9c73a_row1_col2" class="data row1 col2" >0.6817</td>
#       <td id="T_9c73a_row1_col3" class="data row1 col3" >0.1349</td>
#       <td id="T_9c73a_row1_col4" class="data row1 col4" >0.6492</td>
#       <td id="T_9c73a_row1_col5" class="data row1 col5" >0.2148</td>
#       <td id="T_9c73a_row1_col6" class="data row1 col6" >0.1766</td>
#       <td id="T_9c73a_row1_col7" class="data row1 col7" >0.2444</td>
#       <td id="T_9c73a_row1_col8" class="data row1 col8" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_9c73a_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_9c73a_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9c73a_row2_col1" class="data row2 col1" >0.8713</td>
#       <td id="T_9c73a_row2_col2" class="data row2 col2" >0.6923</td>
#       <td id="T_9c73a_row2_col3" class="data row2 col3" >0.1221</td>
#       <td id="T_9c73a_row2_col4" class="data row2 col4" >0.5667</td>
#       <td id="T_9c73a_row2_col5" class="data row2 col5" >0.1974</td>
#       <td id="T_9c73a_row2_col6" class="data row2 col6" >0.1568</td>
#       <td id="T_9c73a_row2_col7" class="data row2 col7" >0.2146</td>
#       <td id="T_9c73a_row2_col8" class="data row2 col8" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_9c73a_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_9c73a_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_9c73a_row3_col1" class="data row3 col1" >0.8697</td>
#       <td id="T_9c73a_row3_col2" class="data row3 col2" >0.5062</td>
#       <td id="T_9c73a_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_9c73a_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_9c73a_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_9c73a_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_9c73a_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_9c73a_row3_col8" class="data row3 col8" >0.2280</td>
#     </tr>
#     <tr>
#       <th id="T_9c73a_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_9c73a_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0bdf7 th {
#   text-align: left;
# }
# #T_0bdf7_row0_col0, #T_0bdf7_row0_col2, #T_0bdf7_row0_col3, #T_0bdf7_row0_col4, #T_0bdf7_row0_col5, #T_0bdf7_row0_col6, #T_0bdf7_row0_col7, #T_0bdf7_row1_col0, #T_0bdf7_row1_col2, #T_0bdf7_row1_col3, #T_0bdf7_row1_col4, #T_0bdf7_row1_col5, #T_0bdf7_row1_col6, #T_0bdf7_row1_col7, #T_0bdf7_row2_col0, #T_0bdf7_row2_col1, #T_0bdf7_row2_col2, #T_0bdf7_row2_col3, #T_0bdf7_row2_col4, #T_0bdf7_row2_col5, #T_0bdf7_row2_col6, #T_0bdf7_row2_col7, #T_0bdf7_row3_col0, #T_0bdf7_row3_col1, #T_0bdf7_row3_col2, #T_0bdf7_row3_col3, #T_0bdf7_row3_col4, #T_0bdf7_row3_col5, #T_0bdf7_row4_col0, #T_0bdf7_row4_col1, #T_0bdf7_row4_col3, #T_0bdf7_row4_col5, #T_0bdf7_row4_col6, #T_0bdf7_row4_col7, #T_0bdf7_row5_col0, #T_0bdf7_row5_col1, #T_0bdf7_row5_col2, #T_0bdf7_row5_col3, #T_0bdf7_row5_col4, #T_0bdf7_row5_col5, #T_0bdf7_row5_col6, #T_0bdf7_row5_col7, #T_0bdf7_row6_col0, #T_0bdf7_row6_col1, #T_0bdf7_row6_col2, #T_0bdf7_row6_col3, #T_0bdf7_row6_col4, #T_0bdf7_row6_col5, #T_0bdf7_row6_col6, #T_0bdf7_row6_col7, #T_0bdf7_row7_col0, #T_0bdf7_row7_col1, #T_0bdf7_row7_col2, #T_0bdf7_row7_col3, #T_0bdf7_row7_col4, #T_0bdf7_row7_col5, #T_0bdf7_row7_col6, #T_0bdf7_row7_col7, #T_0bdf7_row8_col0, #T_0bdf7_row8_col1, #T_0bdf7_row8_col2, #T_0bdf7_row8_col3, #T_0bdf7_row8_col4, #T_0bdf7_row8_col5, #T_0bdf7_row8_col6, #T_0bdf7_row8_col7, #T_0bdf7_row9_col0, #T_0bdf7_row9_col1, #T_0bdf7_row9_col2, #T_0bdf7_row9_col3, #T_0bdf7_row9_col4, #T_0bdf7_row9_col5, #T_0bdf7_row9_col6, #T_0bdf7_row9_col7, #T_0bdf7_row10_col0, #T_0bdf7_row10_col1, #T_0bdf7_row10_col2, #T_0bdf7_row10_col3, #T_0bdf7_row10_col4, #T_0bdf7_row10_col5, #T_0bdf7_row10_col6, #T_0bdf7_row10_col7, #T_0bdf7_row11_col0, #T_0bdf7_row11_col1, #T_0bdf7_row11_col2, #T_0bdf7_row11_col3, #T_0bdf7_row11_col4, #T_0bdf7_row11_col5, #T_0bdf7_row11_col6, #T_0bdf7_row11_col7, #T_0bdf7_row12_col0, #T_0bdf7_row12_col1, #T_0bdf7_row12_col2, #T_0bdf7_row12_col3, #T_0bdf7_row12_col4, #T_0bdf7_row12_col5, #T_0bdf7_row12_col6, #T_0bdf7_row12_col7, #T_0bdf7_row13_col0, #T_0bdf7_row13_col1, #T_0bdf7_row13_col2, #T_0bdf7_row13_col4, #T_0bdf7_row13_col6, #T_0bdf7_row13_col7 {
#   text-align: left;
# }
# #T_0bdf7_row0_col1, #T_0bdf7_row1_col1, #T_0bdf7_row3_col6, #T_0bdf7_row3_col7, #T_0bdf7_row4_col2, #T_0bdf7_row4_col4, #T_0bdf7_row13_col3, #T_0bdf7_row13_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0bdf7_row0_col8, #T_0bdf7_row1_col8, #T_0bdf7_row2_col8, #T_0bdf7_row3_col8, #T_0bdf7_row4_col8, #T_0bdf7_row5_col8, #T_0bdf7_row6_col8, #T_0bdf7_row7_col8, #T_0bdf7_row8_col8, #T_0bdf7_row9_col8, #T_0bdf7_row10_col8, #T_0bdf7_row11_col8, #T_0bdf7_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0bdf7_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0bdf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bdf7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0bdf7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0bdf7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0bdf7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0bdf7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0bdf7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0bdf7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0bdf7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0bdf7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bdf7_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_0bdf7_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_0bdf7_row0_col1" class="data row0 col1" >0.8514</td>
#       <td id="T_0bdf7_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_0bdf7_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_0bdf7_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_0bdf7_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_0bdf7_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_0bdf7_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_0bdf7_row0_col8" class="data row0 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf7_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_0bdf7_row1_col0" class="data row1 col0" >Dummy Classifier</td>
#       <td id="T_0bdf7_row1_col1" class="data row1 col1" >0.8514</td>
#       <td id="T_0bdf7_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_0bdf7_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_0bdf7_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_0bdf7_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_0bdf7_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_0bdf7_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_0bdf7_row1_col8" class="data row1 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf7_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_0bdf7_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_0bdf7_row2_col1" class="data row2 col1" >0.8502</td>
#       <td id="T_0bdf7_row2_col2" class="data row2 col2" >0.5222</td>
#       <td id="T_0bdf7_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_0bdf7_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_0bdf7_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_0bdf7_row2_col6" class="data row2 col6" >-0.0024</td>
#       <td id="T_0bdf7_row2_col7" class="data row2 col7" >-0.0049</td>
#       <td id="T_0bdf7_row2_col8" class="data row2 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf7_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_0bdf7_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_0bdf7_row3_col1" class="data row3 col1" >0.8489</td>
#       <td id="T_0bdf7_row3_col2" class="data row3 col2" >0.6708</td>
#       <td id="T_0bdf7_row3_col3" class="data row3 col3" >0.1742</td>
#       <td id="T_0bdf7_row3_col4" class="data row3 col4" >0.4850</td>
#       <td id="T_0bdf7_row3_col5" class="data row3 col5" >0.2539</td>
#       <td id="T_0bdf7_row3_col6" class="data row3 col6" >0.1904</td>
#       <td id="T_0bdf7_row3_col7" class="data row3 col7" >0.2223</td>
#       <td id="T_0bdf7_row3_col8" class="data row3 col8" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf7_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_0bdf7_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_0bdf7_row4_col1" class="data row4 col1" >0.8464</td>
#       <td id="T_0bdf7_row4_col2" class="data row4 col2" >0.6939</td>
#       <td id="T_0bdf7_row4_col3" class="data row4 col3" >0.1568</td>
#       <td id="T_0bdf7_row4_col4" class="data row4 col4" >0.4933</td>
#       <td id="T_0bdf7_row4_col5" class="data row4 col5" >0.2346</td>
#       <td id="T_0bdf7_row4_col6" class="data row4 col6" >0.1715</td>
#       <td id="T_0bdf7_row4_col7" class="data row4 col7" >0.2095</td>
#       <td id="T_0bdf7_row4_col8" class="data row4 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf7_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_0bdf7_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_
row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_3dd4b_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_3dd4b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_3dd4b_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_3dd4b_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_3dd4b_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_3dd4b_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_3dd4b_row4_col8" class="data row4 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_3dd4b_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_3dd4b_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_3dd4b_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_3dd4b_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_3dd4b_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_3dd4b_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_3dd4b_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_3dd4b_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_3dd4b_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="T_3dd4b_row5_col8" class="data row5 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_3dd4b_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_3dd4b_row6_col0" class="data row6 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3dd4b_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_3dd4b_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_3dd4b_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_3dd4b_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_3dd4b_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_3dd4b_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_3dd4b_row6_col7" class="data row6 col7" >0.0000</td>
#       <td id="T_3dd4b_row6_col8" class="data row6 col8" >0.0080</td>
#     <
# 100%|████████████████████████████████████████████████████████████████████████████| 3/3 [01:25<00:00, 28.54s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 2/2 [02:54<00:00, 87.25s/it]

# %%
aggregated_result_path = EXP_RESULT_PATH / 'result.csv'

if not os.path.exists(aggregated_result_path) :
    exp_result.to_csv(aggregated_result_path)
    
exp_result
# Out:
#    model_name                            Model  Accuracy     AUC  Recall  \
# 0          rf         Random Forest Classifier    0.8769  0.6900  0.1349
# 1          et           Extra Trees Classifier    0.8745  0.6817  0.1349
# 2    lightgbm  Light Gradient Boosting Machine    0.8713  0.6923  0.1221
# 3          lr              Logistic Regression    0.8697  0.5062  0.0000
# 4         qda  Quadratic Discriminant Analysis    0.8697  0.5000  0.0000
# ..        ...                              ...       ...     ...     ...
# 5         ada             Ada Boost Classifier    1.0000  0.0000  1.0000
# 6         lda     Linear Discriminant Analysis    1.0000  0.0000  1.0000
# 7          et           Extra Trees Classifier    1.0000  0.0000  1.0000
# 8    lightgbm  Light Gradient Boosting Machine    1.0000  0.0000  1.0000
# 9       dummy                 Dummy Classifier    1.0000  0.0000  1.0000
#
#      Prec.      F1   Kappa     MCC  TT (Sec)          target  x_data_yaer  \
# 0   0.6762  0.2162  0.1810  0.2532     0.119   Closed_In_1Yr         2018
# 1   0.6492  0.2148  0.1766  0.2444     0.083   Closed_In_1Yr         2018
# 2   0.5667  0.1974  0.1568  0.2146     0.107   Closed_In_1Yr         2018
# 3   0.0000  0.0000  0.0000  0.0000     0.228   Closed_In_1Yr         2018
# 4   0.0000  0.0000  0.0000  0.0000     0.012   Closed_In_1Yr         2018
# ..     ...     ...     ...     ...       ...             ...          ...
# 5   1.0000  1.0000     NaN  0.0000     0.007  Closed_In_2Yrs         2020
# 6   1.0000  1.0000     NaN  0.0000     0.008  Closed_In_2Yrs         2020
# 7   1.0000  1.0000     NaN  0.0000     0.038  Closed_In_2Yrs         2020
# 8   1.0000  1.0000     NaN  0.0000     0.008  Closed_In_2Yrs         2020
# 9   1.0000  1.0000     NaN  0.0000     0.007  Closed_In_2Yrs         2020
#
#            대분류
# 0   제조업(10~34)
# 1   제조업(10~34)
# 2   제조업(10~34)
# 3   제조업(10~34)
# 4   제조업(10~34)
# ..         ...
# 5   건설업(41~42)
# 6   건설업(41~42)
# 7   건설업(41~42)
# 8   건설업(41~42)
# 9   건설업(41~42)
#
# [376 rows x 13 columns]
