# %% [markdown]
# # Prerequisite
#
# Following packages must be installed to run codes below
#
# ```bash
# $ pip3 install openpyxl
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Add project path

# %%
import os
import sys
from pathlib import Path

PROJECT_PATH = Path().resolve().parent.parent
SRC_PATH = PROJECT_PATH / 'src'

sys.path.append(str(SRC_PATH))

# %%
exp_name = 'feature_selection_v2'

# %% [markdown]
# # Load data

# %%
from data_loader import SectorDataLoader

data_loader = SectorDataLoader()
data_finance = (
    data_loader
    .load_dataset()
    .pipe(data_loader.add_beaver_indicator)
    .pipe(data_loader.add_label)
)
data_finance.head()
# Out:
#          BIZ_NO CMP_PFIX_NM   CMP_NM CMP_NM1 CMP_SFIX_NM  \
# 117  1018135422         (주)   한국선박기술     NaN         NaN
# 219  1018154206         (주)     드림미즈     NaN         NaN
# 279  1018163684         NaN  디에프에스서울     NaN         (주)
# 339  1018178760         (주)    대교디앤씨     NaN         NaN
# 406  1018194173         NaN    에코에너지     NaN         (주)
#
#                        CMP_ENM BZ_TYP  CMP_TYP  CMP_SCL  PBCO_GB  ...  \
# 117  Korea Marine Time Service      M      NaN        2        2  ...
# 219         dreammiz Co., Ltd.      M      NaN        2        2  ...
# 279             DFS Seoul Ltd.      M      NaN        2        2  ...
# 339      DAEGYO D & C CO.,LTD.      M      NaN        2        2  ...
# 406        Eco Energy Co.,Ltd.      M      NaN        2        2  ...
#
#      STAT_OCR_DATE_y  Closed_Year  유동자산/부채총계 당기순이익(손실)/자산총계 부채총계/자산총계  \
# 117       20200930.0       2020.0   1.031451       0.038773  0.578094
# 219       20201231.0       2020.0   1.220040       0.001177  0.662356
# 279       20190917.0       2019.0  11.012914       0.046666  0.090794
# 339       20191010.0       2019.0   0.916364      -0.026128  1.091269
# 406       20200831.0       2020.0   1.183355      -0.062095  0.828142
#
#      순운전자본/자산총계  유동부채/유동자산  Years_From_Closed_Year_To_FS  Closed_In_1Yr  \
# 117    0.543045   0.089273                           2.0              0
# 219    0.608449   0.247063                           2.0              0
# 279    0.909114   0.090802                           1.0              1
# 339    0.097514   0.902486                           1.0              1
# 406    0.194625   0.801400                           2.0              0
#
#      Closed_In_2Yrs
# 117               1
# 219               1
# 279               1
# 339               1
# 406               1
#
# [5 rows x 104 columns]

# %%
from data_loader import IndexDataLoader
import pandas as pd

index_features = [
    '3YEAR TREASURY',
    '5YEAR TREASURY',
    '10YEAR TREASURY',
    '3YEAR COPORATE BOND',
    'CD 91DAYS',
    'CALL RATE 1DAY',
    'BASE RATE',
    'YEAR_MONTH',
    'DOW_JONES_COMMODITY_INDEX_PRICE',
    'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE',
    'EXCHANGE_RATE_PRICE',
    'EXCHANGE_RATE_CHANGE_RATE',
    'NATIONWIDE',
    'CAPITAL AREA',
    'NON CAPITAL AREA',
    'CSI',
    'CCI',
    'CLI',
]

index_data_loader = IndexDataLoader()

index_data = (
    index_data_loader.load_interest_rate()
    .merge(
        (
            index_data_loader.load_dow_jones_commodity_index()
            .rename(columns={'PRICE':'DOW_JONES_COMMODITY_INDEX_PRICE',
                            'CHANGE RATE':'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_exchange_rate()
            .rename(columns={'PRICE':'EXCHANGE_RATE_PRICE',
                            'CHANGE RATE':'EXCHANGE_RATE_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_apartment_housing_index()
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
        
    )
    .merge(
        (
            index_data_loader.load_csi()
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_composite_index()
            .rename(columns={'PRICE':'DOW_JONES_COMMODITY_INDEX_PRICE',
                            'CHANGE RATE':'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .assign(year=lambda x : x['YEAR_MONTH'].dt.year)
    .assign(month=lambda x : x['YEAR_MONTH'].dt.month)
    .groupby(['year'])
    [index_features].mean()
    .reset_index(drop=False)
)

index_data
# Out:
#     year  3YEAR TREASURY  5YEAR TREASURY  10YEAR TREASURY  \
# 0   2006             NaN             NaN              NaN
# 1   2007             NaN             NaN              NaN
# 2   2008             NaN             NaN              NaN
# 3   2009             NaN             NaN              NaN
# 4   2010             NaN             NaN              NaN
# 5   2011             NaN             NaN              NaN
# 6   2012             NaN             NaN              NaN
# 7   2013             NaN             NaN              NaN
# 8   2014             NaN             NaN              NaN
# 9   2015             NaN             NaN              NaN
# 10  2016             NaN             NaN              NaN
# 11  2017        1.805000        2.004167         2.283333
# 12  2018        2.100833        2.308333         2.505000
# 13  2019        1.532500        1.590833         1.702500
# 14  2020        0.990000        1.235000         1.500000
# 15  2021        1.385000        1.715000         2.065833
# 16  2022             NaN             NaN              NaN
#
#     3YEAR COPORATE BOND  CD 91DAYS  CALL RATE 1DAY  BASE RATE  \
# 0                   NaN        NaN             NaN        NaN
# 1                   NaN        NaN             NaN        NaN
# 2                   NaN        NaN             NaN        NaN
# 3                   NaN        NaN             NaN        NaN
# 4                   NaN        NaN             NaN        NaN
# 5                   NaN        NaN             NaN        NaN
# 6                   NaN        NaN             NaN        NaN
# 7                   NaN        NaN             NaN        NaN
# 8                   NaN        NaN             NaN        NaN
# 9                   NaN        NaN             NaN        NaN
# 10                  NaN        NaN             NaN        NaN
# 11             2.327500   1.444167        1.260833   1.291667
# 12             2.649167   1.680000        1.521667   1.541667
# 13             2.024167   1.699167        1.591667   1.562500
# 14             2.129167   0.923333        0.698333   0.666667
# 15             2.079167   0.850000        0.612500   0.645833
# 16                  NaN        NaN             NaN        NaN
#
#     DOW_JONES_COMMODITY_INDEX_PRICE  EXCHANGE_RATE_PRICE  NATIONWIDE  \
# 0                               NaN                  NaN   63.841667
# 1                               NaN                  NaN   72.758333
# 2                               NaN                  NaN   76.775000
# 3                               NaN                  NaN   76.058333
# 4                               NaN                  NaN   77.733333
# 5                               NaN                  NaN   83.700000
# 6                               NaN                  NaN   83.883333
# 7                               NaN                  NaN   84.325000
# 8                               NaN                  NaN   88.008333
# 9                               NaN                  NaN   94.008333
# 10                              NaN                  NaN   96.900000
# 11                       580.068333          1121.758333   99.400000
# 12                       625.940833          1098.985000  100.608333
# 13                       614.237500          1164.787500  100.108333
# 14                       590.860000          1177.803333  110.041667
# 15                       878.985000          1146.869167  134.533333
# 16                              NaN                  NaN  139.787500
#
#     CAPITAL AREA  NON CAPITAL AREA         CSI         CCI         CLI
# 0      68.600000         58.416667         NaN         NaN         NaN
# 1      82.441667         60.925000         NaN         NaN         NaN
# 2      89.150000         62.991667         NaN         NaN         NaN
# 3      87.833333         64.200000         NaN         NaN         NaN
# 4      86.833333         69.516667         NaN         NaN         NaN
# 5      86.850000         80.983333         NaN         NaN         NaN
# 6      81.891667         85.250000         NaN         NaN         NaN
# 7      80.333333         87.125000         NaN         NaN         NaN
# 8      83.366667         91.325000         NaN         NaN         NaN
# 9      89.175000         97.658333         NaN         NaN         NaN
# 10     93.716667         99.408333         NaN         NaN         NaN
# 11     98.208333        100.333333         NaN         NaN         NaN
# 12    104.325000         97.441667  104.083333  101.425000  100.058333
# 13    107.183333         94.075000   99.083333  100.258333   98.475000
# 14    122.791667         99.091667   88.333333   98.375000   99.033333
# 15    157.608333        114.841667  103.083333   99.883333  101.150000
# 16    164.037500        119.362500         NaN         NaN         NaN

# %%
data = (
    data_finance
    .assign(year=lambda x : x['결산년월'].astype(str).str[:4].astype(int))
    .merge(
        index_data,
        how='left',
        left_on='year',
        right_on='year'
    )
)
data
# Out:
#            BIZ_NO CMP_PFIX_NM          CMP_NM CMP_NM1 CMP_SFIX_NM  \
# 0      1018135422         (주)          한국선박기술     NaN         NaN
# 1      1018154206         (주)            드림미즈     NaN         NaN
# 2      1018163684         NaN         디에프에스서울     NaN         (주)
# 3      1018178760         (주)           대교디앤씨     NaN         NaN
# 4      1018194173         NaN           에코에너지     NaN         (주)
# ...           ...         ...             ...     ...         ...
# 10516  8998700283         (주)            덕성건설     NaN         NaN
# 10517  8998700283         (주)            덕성건설     NaN         NaN
# 10518  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
# 10519  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
# 10520  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
#
#                                                  CMP_ENM BZ_TYP  CMP_TYP  \
# 0                              Korea Marine Time Service      M      NaN
# 1                                     dreammiz Co., Ltd.      M      NaN
# 2                                         DFS Seoul Ltd.      M      NaN
# 3                                  DAEGYO D & C CO.,LTD.      M      NaN
# 4                                    Eco Energy Co.,Ltd.      M      NaN
# ...                                                  ...    ...      ...
# 10516                             Deokseong Construction      M      NaN
# 10517                             Deokseong Construction      M      NaN
# 10518  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
# 10519  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
# 10520  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
#
#        CMP_SCL  PBCO_GB  ...  CALL RATE 1DAY  BASE RATE  \
# 0            2        2  ...        1.521667   1.541667
# 1            2        2  ...        1.521667   1.541667
# 2            2        2  ...        1.521667   1.541667
# 3            2        2  ...        1.521667   1.541667
# 4            2        2  ...        1.521667   1.541667
# ...        ...      ...  ...             ...        ...
# 10516        2        2  ...        1.521667   1.541667
# 10517        2        2  ...        1.591667   1.562500
# 10518        2        2  ...        1.521667   1.541667
# 10519        2        2  ...        1.591667   1.562500
# 10520        2        2  ...        0.698333   0.666667
#
#       DOW_JONES_COMMODITY_INDEX_PRICE EXCHANGE_RATE_PRICE  NATIONWIDE  \
# 0                          625.940833         1098.985000  100.608333
# 1                          625.940833         1098.985000  100.608333
# 2                          625.940833         1098.985000  100.608333
# 3                          625.940833         1098.985000  100.608333
# 4                          625.940833         1098.985000  100.608333
# ...                               ...                 ...         ...
# 10516                      625.940833         1098.985000  100.608333
# 10517                      614.237500         1164.787500  100.108333
# 10518                      625.940833         1098.985000  100.608333
# 10519                      614.237500         1164.787500  100.108333
# 10520                      590.860000         1177.803333  110.041667
#
#        CAPITAL AREA  NON CAPITAL AREA         CSI         CCI         CLI
# 0        104.325000         97.441667  104.083333  101.425000  100.058333
# 1        104.325000         97.441667  104.083333  101.425000  100.058333
# 2        104.325000         97.441667  104.083333  101.425000  100.058333
# 3        104.325000         97.441667  104.083333  101.425000  100.058333
# 4        104.325000         97.441667  104.083333  101.425000  100.058333
# ...             ...               ...         ...         ...         ...
# 10516    104.325000         97.441667  104.083333  101.425000  100.058333
# 10517    107.183333         94.075000   99.083333  100.258333   98.475000
# 10518    104.325000         97.441667  104.083333  101.425000  100.058333
# 10519    107.183333         94.075000   99.083333  100.258333   98.475000
# 10520    122.791667         99.091667   88.333333   98.375000   99.033333
#
# [10521 rows x 120 columns]

# %% [markdown]
# # Baseline classifier using Beaver's features

# %%
from project_paths import DATA_PATH

sectors = [
    '제조업(10~34)',
    '부동산업(68)',
    '도매 및 소매업(45~47)',
    '숙박 및 음식점업(55~56)',
    '건설업(41~42)'
]

beaver_features = [
    '유동자산/부채총계',
    '당기순이익(손실)/자산총계',
    '부채총계/자산총계',
    '순운전자본/자산총계',
    '유동부채/유동자산'
]

extended_financial_features = [
    '유동자산',
    '매출채권',
    '비유동자산',
    '유형자산',
    '자산총계',
    '유동부채',
    '비유동부채',
    '부  채  총  계',
    '자본금',
    '이익잉여금(결손금）',
    '자본총계',
    '매출액',
    '판매비와관리비',
    '영업이익（손실）',
    '법인세비용차감전순손익',
    '법인세비용',
    '당기순이익(손실)',
    '기업순이익률(%)',
    '유보액/총자산(%)',
    '유보액/납입자본(%)',
    '매출액총이익률(%)',
    '매출액영업이익률(%)',
    '매출액순이익률(%)',
    '수지비율(%)',
    '경상수지비율',
    '영업비율(%)',
    '금융비용대매출액비율(%',
    '금융비용대부채비율(%)',
    '금융비용대총비용비율(%',
    '부채비율(%)',
    '차입금의존도(%)',
    '자기자본비율(%)',
    '순운전자본비율(%)',
    '유동부채비율(%)',
    '비유동부채비율(%)',
    '부채총계대 매출액(%)',
    '총자본회전율(회)',
    '재고자산회전율(회)',
    '매출채권회전율(회)',
    '매입채무회전율(회)',
    '미수금',
    '매출원가',
    '무형자산',
    '재고자산',
]

years_to_close = [
    'Closed_In_1Yr',
    'Closed_In_2Yrs',
]

x_data_year = list(range(2018, 2020))

EXP_RESULT_PATH = DATA_PATH / 'experiment_result' / exp_name

if not os.path.exists(EXP_RESULT_PATH) : 
    os.mkdir(EXP_RESULT_PATH)

# %%
import numpy as np
import pandas as pd
from pycaret.classification import ClassificationExperiment
from tqdm import tqdm

# %%
exp_result = None

for target_years_to_close in tqdm(years_to_close) : 
    for x_data_target_year in tqdm(x_data_year, leave=True) : 
        for sector in sectors : 

            filename = EXP_RESULT_PATH / f'Beaver_baseline_{sector}_{target_years_to_close}_{x_data_target_year}.csv'

            if not os.path.exists(filename) : 

                data_to_train = (
                    data
                    .loc[~data[beaver_features[0]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[1]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[2]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[3]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[4]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[lambda x : pd.to_datetime(x['결산년월'], format='%Y%m%d').dt.year==x_data_target_year]
                    .loc[lambda x : x['대분류']==sector]
                )

                exp = ClassificationExperiment()

                exp.setup(
                    (
                        data_to_train
                        .loc[:, beaver_features
                             +extended_financial_features
                             +index_data.drop(['year'], axis=1).columns.tolist()
                             +[target_years_to_close]]
                        .reset_index(drop=True)
                    ),
                    target=target_years_to_close,
                    feature_selection=True,
                    #remove_multicollinearity = True,
                )

                models = exp.compare_models(sort='AUC', n_select=3)
                tuned_models = [exp.tune_model(x) for x in models]
                
                #if target_years_to_close == 'Closed_In_1Yr' :
                blended_model = exp.blend_models(estimator_list=tuned_models, fold=5, method = 'soft')
                result = (
                    exp.pull()
                    .assign(target=target_years_to_close)
                    .assign(x_data_yaer=x_data_target_year)
                    .assign(대분류=sector)
                    .reset_index(drop=False)
                    .rename(columns={'index':'model_name'})
                )
                result['feature_selection'] = str(exp.dataset_transformed.columns.tolist())
                result.to_csv(filename)

            else : 
                result = pd.read_csv(filename)

            if exp_result is None : 
                exp_result = result
            else : 
                exp_result = pd.concat([exp_result, result], axis=0)
# Out:
#   0%|                                                                                    | 0/2 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 55.90it/s]
#
#   0%|                                                                                    | 0/2 [00:00<?, ?it/s]
# <style type="text/css">
# #T_8c0a6_row9_col1, #T_8c0a6_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8c0a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c0a6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8c0a6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c0a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c0a6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8c0a6_row0_col1" class="data row0 col1" >8903</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c0a6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8c0a6_row1_col1" class="data row1 col1" >Closed_In_2Yrs</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c0a6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8c0a6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c0a6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8c0a6_row3_col1" class="data row3 col1" >(1800, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c0a6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8c0a6_row4_col1" class="data row4 col1" >(1800, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c0a6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8c0a6_row5_col1" class="data row5 col1" >(1259, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8c0a6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8c0a6_row6_col1" class="data row6 col1" >(541, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8c0a6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8c0a6_row7_col1" class="data row7 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8c0a6_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_8c0a6_row8_col1" class="data row8 col1" >84.8%</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8c0a6_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_8c0a6_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8c0a6_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_8c0a6_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8c0a6_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_8c0a6_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8c0a6_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_8c0a6_row12_col1" class="data row12 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8c0a6_row13_col0" class="data row13 col0" >Low variance threshold</td>
#       <td id="T_8c0a6_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8c0a6_row14_col0" class="data row14 col0" >Feature selection</td>
#       <td id="T_8c0a6_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8c0a6_row15_col0" class="data row15 col0" >Feature selection method</td>
#       <td id="T_8c0a6_row15_col1" class="data row15 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8c0a6_row16_col0" class="data row16 col0" >Feature selection estimator</td>
#       <td id="T_8c0a6_row16_col1" class="data row16 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8c0a6_row17_col0" class="data row17 col0" >Number of features selected</td>
#       <td id="T_8c0a6_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8c0a6_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_8c0a6_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8c0a6_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_8c0a6_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8c0a6_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_8c0a6_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8c0a6_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_8c0a6_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8c0a6_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_8c0a6_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8c0a6_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_8c0a6_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8c0a6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8c0a6_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_8c0a6_row24_col1" class="data row24 col1" >d23d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_08a0e th {
#   text-align: left;
# }
# #T_08a0e_row0_col0, #T_08a0e_row0_col1, #T_08a0e_row0_col3, #T_08a0e_row0_col4, #T_08a0e_row0_col5, #T_08a0e_row0_col6, #T_08a0e_row0_col7, #T_08a0e_row1_col0, #T_08a0e_row1_col1, #T_08a0e_row1_col2, #T_08a0e_row1_col3, #T_08a0e_row1_col4, #T_08a0e_row1_col5, #T_08a0e_row1_col6, #T_08a0e_row1_col7, #T_08a0e_row2_col0, #T_08a0e_row2_col2, #T_08a0e_row2_col3, #T_08a0e_row2_col5, #T_08a0e_row3_col0, #T_08a0e_row3_col1, #T_08a0e_row3_col2, #T_08a0e_row3_col3, #T_08a0e_row3_col4, #T_08a0e_row3_col5, #T_08a0e_row3_col6, #T_08a0e_row3_col7, #T_08a0e_row4_col0, #T_08a0e_row4_col1, #T_08a0e_row4_col2, #T_08a0e_row4_col3, #T_08a0e_row4_col4, #T_08a0e_row4_col5, #T_08a0e_row4_col6, #T_08a0e_row4_col7, #T_08a0e_row5_col0, #T_08a0e_row5_col1, #T_08a0e_row5_col2, #T_08a0e_row5_col3, #T_08a0e_row5_col4, #T_08a0e_row5_col5, #T_08a0e_row5_col6, #T_08a0e_row5_col7, #T_08a0e_row6_col0, #T_08a0e_row6_col1, #T_08a0e_row6_col2, #T_08a0e_row6_col3, #T_08a0e_row6_col4, #T_08a0e_row6_col5, #T_08a0e_row6_col6, #T_08a0e_row6_col7, #T_08a0e_row7_col0, #T_08a0e_row7_col1, #T_08a0e_row7_col2, #T_08a0e_row7_col4, #T_08a0e_row7_col6, #T_08a0e_row7_col7, #T_08a0e_row8_col0, #T_08a0e_row8_col1, #T_08a0e_row8_col2, #T_08a0e_row8_col3, #T_08a0e_row8_col4, #T_08a0e_row8_col5, #T_08a0e_row8_col6, #T_08a0e_row8_col7, #T_08a0e_row9_col0, #T_08a0e_row9_col1, #T_08a0e_row9_col2, #T_08a0e_row9_col3, #T_08a0e_row9_col4, #T_08a0e_row9_col5, #T_08a0e_row9_col6, #T_08a0e_row9_col7, #T_08a0e_row10_col0, #T_08a0e_row10_col1, #T_08a0e_row10_col2, #T_08a0e_row10_col3, #T_08a0e_row10_col4, #T_08a0e_row10_col5, #T_08a0e_row10_col6, #T_08a0e_row10_col7, #T_08a0e_row11_col0, #T_08a0e_row11_col1, #T_08a0e_row11_col2, #T_08a0e_row11_col3, #T_08a0e_row11_col4, #T_08a0e_row11_col5, #T_08a0e_row11_col6, #T_08a0e_row11_col7, #T_08a0e_row12_col0, #T_08a0e_row12_col1, #T_08a0e_row12_col2, #T_08a0e_row12_col3, #T_08a0e_row12_col4, #T_08a0e_row12_col5, #T_08a0e_row12_col6, #T_08a0e_row12_col7, #T_08a0e_row13_col0, #T_08a0e_row13_col1, #T_08a0e_row13_col2, #T_08a0e_row13_col3, #T_08a0e_row13_col4, #T_08a0e_row13_col5, #T_08a0e_row13_col6, #T_08a0e_row13_col7 {
#   text-align: left;
# }
# #T_08a0e_row0_col2, #T_08a0e_row2_col1, #T_08a0e_row2_col4, #T_08a0e_row2_col6, #T_08a0e_row2_col7, #T_08a0e_row7_col3, #T_08a0e_row7_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_08a0e_row0_col8, #T_08a0e_row1_col8, #T_08a0e_row2_col8, #T_08a0e_row3_col8, #T_08a0e_row4_col8, #T_08a0e_row5_col8, #T_08a0e_row6_col8, #T_08a0e_row7_col8, #T_08a0e_row8_col8, #T_08a0e_row9_col8, #T_08a0e_row10_col8, #T_08a0e_row11_col8, #T_08a0e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_08a0e_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_08a0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08a0e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_08a0e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_08a0e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_08a0e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_08a0e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_08a0e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_08a0e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_08a0e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_08a0e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08a0e_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_08a0e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_08a0e_row0_col1" class="data row0 col1" >0.5799</td>
#       <td id="T_08a0e_row0_col2" class="data row0 col2" >0.6005</td>
#       <td id="T_08a0e_row0_col3" class="data row0 col3" >0.4991</td>
#       <td id="T_08a0e_row0_col4" class="data row0 col4" >0.5391</td>
#       <td id="T_08a0e_row0_col5" class="data row0 col5" >0.5171</td>
#       <td id="T_08a0e_row0_col6" class="data row0 col6" >0.1467</td>
#       <td id="T_08a0e_row0_col7" class="data row0 col7" >0.1474</td>
#       <td id="T_08a0e_row0_col8" class="data row0 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_08a0e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_08a0e_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_08a0e_row1_col1" class="data row1 col1" >0.5782</td>
#       <td id="T_08a0e_row1_col2" class="data row1 col2" >0.5981</td>
#       <td id="T_08a0e_row1_col3" class="data row1 col3" >0.4238</td>
#       <td id="T_08a0e_row1_col4" class="data row1 col4" >0.5462</td>
#       <td id="T_08a0e_row1_col5" class="data row1 col5" >0.4769</td>
#       <td id="T_08a0e_row1_col6" class="data row1 col6" >0.1328</td>
#       <td id="T_08a0e_row1_col7" class="data row1 col7" >0.1361</td>
#       <td id="T_08a0e_row1_col8" class="data row1 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_08a0e_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T
level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eae09_row5_col0" class="data row5 col0" >0.5476</td>
#       <td id="T_eae09_row5_col1" class="data row5 col1" >0.5784</td>
#       <td id="T_eae09_row5_col2" class="data row5 col2" >0.4386</td>
#       <td id="T_eae09_row5_col3" class="data row5 col3" >0.5000</td>
#       <td id="T_eae09_row5_col4" class="data row5 col4" >0.4673</td>
#       <td id="T_eae09_row5_col5" class="data row5 col5" >0.0771</td>
#       <td id="T_eae09_row5_col6" class="data row5 col6" >0.0776</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eae09_row6_col0" class="data row6 col0" >0.6349</td>
#       <td id="T_eae09_row6_col1" class="data row6 col1" >0.6354</td>
#       <td id="T_eae09_row6_col2" class="data row6 col2" >0.5439</td>
#       <td id="T_eae09_row6_col3" class="data row6 col3" >0.6078</td>
#       <td id="T_eae09_row6_col4" class="data row6 col4" >0.5741</td>
#       <td id="T_eae09_row6_col5" class="data row6 col5" >0.2564</td>
#       <td id="T_eae09_row6_col6" class="data row6 col6" >0.2576</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eae09_row7_col0" class="data row7 col0" >0.5952</td>
#       <td id="T_eae09_row7_col1" class="data row7 col1" >0.5980</td>
#       <td id="T_eae09_row7_col2" class="data row7 col2" >0.4561</td>
#       <td id="T_eae09_row7_col3" class="data row7 col3" >0.5652</td>
#       <td id="T_eae09_row7_col4" class="data row7 col4" >0.5049</td>
#       <td id="T_eae09_row7_col5" class="data row7 col5" >0.1691</td>
#       <td id="T_eae09_row7_col6" class="data row7 col6" >0.1719</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eae09_row8_col0" class="data row8 col0" >0.5635</td>
#       <td id="T_eae09_row8_col1" class="data row8 col1" >0.5423</td>
#       <td id="T_eae09_row8_col2" class="data row8 col2" >0.4386</td>
#       <td id="T_eae09_row8_col3" class="data row8 col3" >0.5208</td>
#       <td id="T_eae09_row8_col4" class="data row8 col4" >0.4762</td>
#       <td id="T_eae09_row8_col5" class="data row8 col5" >0.1067</td>
#       <td id="T_eae09_row8_col6" class="data row8 col6" >0.1079</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eae09_row9_col0" class="data row9 col0" >0.6000</td>
#       <td id="T_eae09_row9_col1" class="data row9 col1" >0.6244</td>
#       <td id="T_eae09_row9_col2" class="data row9 col2" >0.4561</td>
#       <td id="T_eae09_row9_col3" class="data row9 col3" >0.5778</td>
#       <td id="T_eae09_row9_col4" class="data row9 col4" >0.5098</td>
#       <td id="T_eae09_row9_col5" class="data row9 col5" >0.1798</td>
#       <td id="T_eae09_row9_col6" class="data row9 col6" >0.1834</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eae09_row10_col0" class="data row10 col0" >0.5902</td>
#       <td id="T_eae09_row10_col1" class="data row10 col1" >0.6090</td>
#       <td id="T_eae09_row10_col2" class="data row10 col2" >0.4763</td>
#       <td id="T_eae09_row10_col3" class="data row10 col3" >0.5569</td>
#       <td id="T_eae09_row10_col4" class="data row10 col4" >0.5131</td>
#       <td id="T_eae09_row10_col5" class="data row10 col5" >0.1630</td>
#       <td id="T_eae09_row10_col6" class="data row10 col6" >0.1647</td>
#     </tr>
#     <tr>
#       <th id="T_eae09_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_eae09_row11_col0" class="data row11 col0" >0.0260</td>
#       <td id="T_eae09_row11_col1" class="data row11 col1" >0.0342</td>
#       <td id="T_eae09_row11_col2" class="data row11 col2" >0.0309</td>
#       <td id="T_eae09_row11_col3" class="data row11 col3" >0.0345</td>
#       <td id="T_eae09_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_5b371_row5_col0, #T_5b371_row5_col1, #T_5b371_row5_col2, #T_5b371_row5_col3, #T_5b371_row5_col4, #T_5b371_row5_col5, #T_5b371_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b371">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b371_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b371_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b371_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b371_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b371_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b371_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b371_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b371_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b371_row0_col0" class="data row0 col0" >0.5516</td>
#       <td id="T_5b371_row0_col1" class="data row0 col1" >0.5375</td>
#       <td id="T_5b371_row0_col2" class="data row0 col2" >0.4087</td>
#       <td id="T_5b371_row0_col3" class="data row0 col3" >0.5109</td>
#       <td id="T_5b371_row0_col4" class="data row0 col4" >0.4541</td>
#       <td id="T_5b371_row0_col5" class="data row0 col5" >0.0815</td>
#       <td id="T_5b371_row0_col6" class="data row0 col6" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b371_row1_col0" class="data row1 col0" >0.5873</td>
#       <td id="T_5b371_row1_col1" class="data row1 col1" >0.5882</td>
#       <td id="T_5b371_row1_col2" class="data row1 col2" >0.4298</td>
#       <td id="T_5b371_row1_col3" class="data row1 col3" >0.5568</td>
#       <td id="T_5b371_row1_col4" class="data row1 col4" >0.4851</td>
#       <td id="T_5b371_row1_col5" class="data row1 col5" >0.1502</td>
#       <td id="T_5b371_row1_col6" class="data row1 col6" >0.1537</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b371_row2_col0" class="data row2 col0" >0.5556</td>
#       <td id="T_5b371_row2_col1" class="data row2 col1" >0.5999</td>
#       <td id="T_5b371_row2_col2" class="data row2 col2" >0.4561</td>
#       <td id="T_5b371_row2_col3" class="data row2 col3" >0.5098</td>
#       <td id="T_5b371_row2_col4" class="data row2 col4" >0.4815</td>
#       <td id="T_5b371_row2_col5" class="data row2 col5" >0.0947</td>
#       <td id="T_5b371_row2_col6" class="data row2 col6" >0.0951</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b371_row3_col0" class="data row3 col0" >0.5952</td>
#       <td id="T_5b371_row3_col1" class="data row3 col1" >0.5883</td>
#       <td id="T_5b371_row3_col2" class="data row3 col2" >0.3947</td>
#       <td id="T_5b371_row3_col3" class="data row3 col3" >0.5769</td>
#       <td id="T_5b371_row3_col4" class="data row3 col4" >0.4688</td>
#       <td id="T_5b371_row3_col5" class="data row3 col5" >0.1600</td>
#       <td id="T_5b371_row3_col6" class="data row3 col6" >0.1675</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b371_row4_col0" class="data row4 col0" >0.5618</td>
#       <td id="T_5b371_row4_col1" class="data row4 col1" >0.5510</td>
#       <td id="T_5b371_row4_col2" class="data row4 col2" >0.3684</td>
#       <td id="T_5b371_row4_col3" class="data row4 col3" >0.5250</td>
#       <td id="T_5b371_row4_col4" class="data row4 col4" >0.4330</td>
#       <td id="T_5b371_row4_col5" class="data row4 col5" >0.0934</td>
#       <td id="T_5b371_row4_col6" class="data row4 col6" >0.0973</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5b371_row5_col0" class="data row5 col0" >0.5703</td>
#       <td id="T_5b371_row5_col1" class="data row5 col1" >0.5730</td>
#       <td id="T_5b371_row5_col2" class="data row5 col2" >0.4116</td>
#       <td id="T_5b371_row5_col3" class="data row5 col3" >0.5359</td>
#       <td id="T_5b371_row5_col4" class="data row5 col4" >0.4645</td>
#       <td id="T_5b371_row5_col5" class="data row5 col5" >0.1160</td>
#       <td id="T_5b371_row5_col6" class="data row5 col6" >0.1193</td>
#     </tr>
#     <tr>
#       <th id="T_5b371_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5b371_row6_col0" class="data row6 col0" >0.0176</td>
#       <td id="T_5b371_row6_col1" class="data row6 col1" >0.0242</td>
#       <td id="T_5b371_row6_col2" class="data row6 col2" >0.0299</td>
#       <td id="T_5b371_row6_col3" class="data row6 col3" >0.0266</td>
#       <td id="T_5b371_row6_col4" class="data row6 col4" >0.0192</td>
#       <td id="T_5b371_row6_col5" class="data row6 col5" >0.0324</td>
#       <td id="T_5b371_row6_col6" class="data row6 col6" >0.0343</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# <style type="text/css">
# #T_efa01_row9_col1, #T_efa01_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_efa01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efa01_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_efa01_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efa01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efa01_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_efa01_row0_col1" class="data row0 col1" >5602</td>
#     </tr>
#     <tr>
#       <th id="T_efa01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efa01_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_efa01_row1_col1" class="data row1 col1" >Closed_In_2Yrs</td>
#     </tr>
#     <tr>
#       <th id="T_efa01_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efa01_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_efa01_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_efa01_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efa01_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_efa01_row3_col1" class="data row3 col1" >(323, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_efa01_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efa01_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_efa01_row4_col1" class="data row4 col1" >(323, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_efa01_level0_row5" class="row_heading level0 row5" >5</th>
# ...
#       <td id="T_53628_row7_col5" class="data row7 col5" >0.3846</td>
#       <td id="T_53628_row7_col6" class="data row7 col6" >0.4042</td>
#     </tr>
#     <tr>
#       <th id="T_53628_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_53628_row8_col0" class="data row8 col0" >0.5000</td>
#       <td id="T_53628_row8_col1" class="data row8 col1" >0.3533</td>
#       <td id="T_53628_row8_col2" class="data row8 col2" >0.6000</td>
#       <td id="T_53628_row8_col3" class="data row8 col3" >0.6923</td>
#       <td id="T_53628_row8_col4" class="data row8 col4" >0.6429</td>
#       <td id="T_53628_row8_col5" class="data row8 col5" >-0.1765</td>
#       <td id="T_53628_row8_col6" class="data row8 col6" >-0.1816</td>
#     </tr>
#     <tr>
#       <th id="T_53628_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_53628_row9_col0" class="data row9 col0" >0.4000</td>
#       <td id="T_53628_row9_col1" class="data row9 col1" >0.2976</td>
#       <td id="T_53628_row9_col2" class="data row9 col2" >0.3571</td>
#       <td id="T_53628_row9_col3" class="data row9 col3" >0.6250</td>
#       <td id="T_53628_row9_col4" class="data row9 col4" >0.4545</td>
#       <td id="T_53628_row9_col5" class="data row9 col5" >-0.1111</td>
#       <td id="T_53628_row9_col6" class="data row9 col6" >-0.1336</td>
#     </tr>
#     <tr>
#       <th id="T_53628_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_53628_row10_col0" class="data row10 col0" >0.6490</td>
#       <td id="T_53628_row10_col1" class="data row10 col1" >0.6404</td>
#       <td id="T_53628_row10_col2" class="data row10 col2" >0.7424</td>
#       <td id="T_53628_row10_col3" class="data row10 col3" >0.7670</td>
#       <td id="T_53628_row10_col4" class="data row10 col4" >0.7414</td>
#       <td id="T_53628_row10_col5" class="data row10 col5" >0.1417</td>
#       <td id="T_53628_row10_col6" class="data row10 col6" >0.1510</td>
#     </tr>
#     <tr>
#       <th id="T_53628_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_53628_row11_col0" class="data row11 col0" >0.1525</td>
#       <td id="T_53628_row11_col1" class="data row11 col1" >0.1998</td>
#       <td id="T_53628_row11_col2" class="data row11 col2" >0.1985</td>
#       <td id="T_53628_row11_col3" class="data row11 col3" >0.1061</td>
#       <td id="T_53628_ro
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_76426_row10_col0, #T_76426_row10_col1, #T_76426_row10_col2, #T_76426_row10_col3, #T_76426_row10_col4, #T_76426_row10_col5, #T_76426_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_76426">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76426_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_76426_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_76426_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_76426_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_76426_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_76426_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_76426_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76426_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76426_row0_col0" class="data row0 col0" >0.7143</td>
#       <td id="T_76426_row0_col1" class="data row0 col1" >0.6500</td>
#       <td id="T_76426_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_76426_row0_col3" class="data row0 col3" >0.7143</td>
#       <td id="T_76426_row0_col4" class="data row0 col4" >0.8333</td>
#       <td id="T_76426_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_76426_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76426_row1_col0" class="data row1 col0" >0.7143</td>
#       <td id="T_76426_row1_col1" class="data row1 col1" >0.7222</td>
#       <td id="T_76426_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_76426_row1_col3" class="data row1 col3" >0.7143</td>
#       <td id="T_76426_row1_col4" class="data row1 col4" >0.8333</td>
#       <td id="T_76426_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_76426_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76426_row2_col0" class="data row2 col0" >0.7619</td>
#       <td id="T_76426_row2_col1" class="data row2 col1" >0.6667</td>
#       <td id="T_76426_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_76426_row2_col3" class="data row2 col3" >0.7500</td>
#       <td id="T_76426_row2_col4" class="data row2 col4" >0.8571</td>
#       <td id="T_76426_row2_col5" class="data row2 col5" >0.2222</td>
#       <td id="T_76426_row2_col6" class="data row2 col6" >0.3536</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76426_row3_col0" class="data row3 col0" >0.7143</td>
#       <td id="T_76426_row3_col1" class="data row3 col1" >0.7111</td>
#       <td id="T_76426_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_76426_row3_col3" class="data row3 col3" >0.7143</td>
#       <td id="T_76426_row3_col4" class="data row3 col4" >0.8333</td>
#       <td id="T_76426_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_76426_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76426_row4_col0" class="data row4 col0" >0.7143</td>
#       <td id="T_76426_row4_col1" class="data row4 col1" >0.6667</td>
#       <td id="T_76426_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_76426_row4_col3" class="data row4 col3" >0.7143</td>
#       <td id="T_76426_row4_col4" class="data row4 col4" >0.8333</td>
#       <td id="T_76426_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_76426_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76426_row5_col0" class="data row5 col0" >0.7500</td>
#       <td id="T_76426_row5_col1" class="data row5 col1" >0.6267</td>
#       <td id="T_76426_row5_col2" class="data row5 col2" >0.9333</td>
#       <td id="T_76426_row5_col3" class="data row5 col3" >0.7778</td>
#       <td id="T_76426_row5_col4" class="data row5 col4" >0.8485</td>
#       <td id="T_76426_row5_col5" class="data row5 col5" >0.1667</td>
#       <td id="T_76426_row5_col6" class="data row5 col6" >0.1925</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76426_row6_col0" class="data row6 col0" >0.7500</td>
#       <td id="T_76426_row6_col1" class="data row6 col1" >0.9333</td>
#       <td id="T_76426_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_76426_row6_col3" class="data row6 col3" >0.7500</td>
#       <td id="T_76426_row6_col4" class="data row6 col4" >0.8571</td>
#       <td id="T_76426_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_76426_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76426_row7_col0" class="data row7 col0" >0.7500</td>
#       <td id="T_76426_row7_col1" class="data row7 col1" >0.3933</td>
#       <td id="T_76426_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_76426_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_76426_row7_col4" class="data row7 col4" >0.8571</td>
#       <td id="T_76426_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_76426_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76426_row8_col0" class="data row8 col0" >0.7000</td>
#       <td id="T_76426_row8_col1" class="data row8 col1" >0.5467</td>
#       <td id="T_76426_row8_col2" class="data row8 col2" >0.9333</td>
#       <td id="T_76426_row8_col3" class="data row8 col3" >0.7368</td>
#       <td id="T_76426_row8_col4" class="data row8 col4" >0.8235</td>
#       <td id="T_76426_row8_col5" class="data row8 col5" >-0.0909</td>
#       <td id="T_76426_row8_col6" class="data row8 col6" >-0.1325</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76426_row9_col0" class="data row9 col0" >0.7000</td>
#       <td id="T_76426_row9_col1" class="data row9 col1" >0.3512</td>
#       <td id="T_76426_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_76426_row9_col3" class="data row9 col3" >0.7000</td>
#       <td id="T_76426_row9_col4" class="data row9 col4" >0.8235</td>
#       <td id="T_76426_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_76426_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_76426_row10_col0" class="data row10 col0" >0.7269</td>
#       <td id="T_76426_row10_col1" class="data row10 col1" >0.6268</td>
#       <td id="T_76426_row10_col2" class="data row10 col2" >0.9867</td>
#       <td id="T_76426_row10_col3" class="data row10 col3" >0.7322</td>
#       <td id="T_76426_row10_col4" class="data row10 col4" >0.8400</td>
#       <td id="T_76426_row10_col5" class="data row10 col5" >0.0298</td>
#       <td id="T_76426_row10_col6" class="data row10 col6" >0.0414</td>
#     </tr>
#     <tr>
#       <th id="T_76426_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_76426_row11_col0" class="data row11 col0" >0.0222</td>
#       <td id="T_76426_row11_col1" class="data row11 col1" >0.1584</td>
#       <td id="T_76426_row11_col2" class="data row11 col2" >0.0267</td>
#       <td id="T_76426_row11_col3" class="data row11 col3" >0.0232</td>
#       <td id="T_76426_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_8806f_row5_col0, #T_8806f_row5_col1, #T_8806f_row5_col2, #T_8806f_row5_col3, #T_8806f_row5_col4, #T_8806f_row5_col5, #T_8806f_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8806f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8806f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8806f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8806f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8806f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8806f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8806f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8806f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8806f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8806f_row0_col0" class="data row0 col0" >0.7317</td>
#       <td id="T_8806f_row0_col1" class="data row0 col1" >0.4455</td>
#       <td id="T_8806f_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_8806f_row0_col3" class="data row0 col3" >0.7568</td>
#       <td id="T_8806f_row0_col4" class="data row0 col4" >0.8358</td>
#       <td id="T_8806f_row0_col5" class="data row0 col5" >0.1442</td>
#       <td id="T_8806f_row0_col6" class="data row0 col6" >0.1719</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8806f_row1_col0" class="data row1 col0" >0.6585</td>
#       <td id="T_8806f_row1_col1" class="data row1 col1" >0.7212</td>
#       <td id="T_8806f_row1_col2" class="data row1 col2" >0.8333</td>
#       <td id="T_8806f_row1_col3" class="data row1 col3" >0.7353</td>
#       <td id="T_8806f_row1_col4" class="data row1 col4" >0.7812</td>
#       <td id="T_8806f_row1_col5" class="data row1 col5" >0.0171</td>
#       <td id="T_8806f_row1_col6" class="data row1 col6" >0.0178</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8806f_row2_col0" class="data row2 col0" >0.7073</td>
#       <td id="T_8806f_row2_col1" class="data row2 col1" >0.4864</td>
#       <td id="T_8806f_row2_col2" class="data row2 col2" >0.9667</td>
#       <td id="T_8806f_row2_col3" class="data row2 col3" >0.7250</td>
#       <td id="T_8806f_row2_col4" class="data row2 col4" >0.8286</td>
#       <td id="T_8806f_row2_col5" class="data row2 col5" >-0.0468</td>
#       <td id="T_8806f_row2_col6" class="data row2 col6" >-0.0957</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8806f_row3_col0" class="data row3 col0" >0.7317</td>
#       <td id="T_8806f_row3_col1" class="data row3 col1" >0.7333</td>
#       <td id="T_8806f_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_8806f_row3_col3" class="data row3 col3" >0.7317</td>
#       <td id="T_8806f_row3_col4" class="data row3 col4" >0.8451</td>
#       <td id="T_8806f_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_8806f_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8806f_row4_col0" class="data row4 col0" >0.5366</td>
#       <td id="T_8806f_row4_col1" class="data row4 col1" >0.4756</td>
#       <td id="T_8806f_row4_col2" class="data row4 col2" >0.5862</td>
#       <td id="T_8806f_row4_col3" class="data row4 col3" >0.7083</td>
#       <td id="T_8806f_row4_col4" class="data row4 col4" >0.6415</td>
#       <td id="T_8806f_row4_col5" class="data row4 col5" >0.0026</td>
#       <td id="T_8806f_row4_col6" class="data row4 col6" >0.0027</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_8806f_row5_col0" class="data row5 col0" >0.6732</td>
#       <td id="T_8806f_row5_col1" class="data row5 col1" >0.5724</td>
#       <td id="T_8806f_row5_col2" class="data row5 col2" >0.8639</td>
#       <td id="T_8806f_row5_col3" class="data row5 col3" >0.7314</td>
#       <td id="T_8806f_row5_col4" class="data row5 col4" >0.7864</td>
#       <td id="T_8806f_row5_col5" class="data row5 col5" >0.0234</td>
#       <td id="T_8806f_row5_col6" class="data row5 col6" >0.0193</td>
#     </tr>
#     <tr>
#       <th id="T_8806f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_8806f_row6_col0" class="data row6 col0" >0.0733</td>
#       <td id="T_8806f_row6_col1" class="data row6 col1" >0.1272</td>
#       <td id="T_8806f_row6_col2" class="data row6 col2" >0.1496</td>
#       <td id="T_8806f_row6_col3" class="data row6 col3" >0.0157</td>
#       <td id="T_8806f_row6_col4" class="data row6 col4" >0.0757</td>
#       <td id="T_8806f_row6_col5" class="data row6 col5" >0.0641</td>
#       <td id="T_8806f_row6_col6" class="data row6 col6" >0.0862</td>
#     </tr>
#   </tbody>
# </table>
# 100%|███████████████████████████████████████████████████████████████████████████| 2/2 [04:16<00:00, 128.48s/it]
# 100%|███████████████████████████████████████████████████████████████████████████| 2/2 [04:16<00:00, 128.50s/it]

# %%
aggregated_result_path = EXP_RESULT_PATH / 'result.csv'

if not os.path.exists(aggregated_result_path) :
    exp_result.to_csv(aggregated_result_path)
    
exp_result
# Out:
#     Unnamed: 0  Fold  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0          0.0     0    0.8690  0.6121  0.0000  0.0000  0.0000  0.0000
# 1          1.0     1    0.8690  0.6165  0.0000  0.0000  0.0000  0.0000
# 2          2.0     2    0.8690  0.7103  0.0000  0.0000  0.0000  0.0000
# 3          3.0     3    0.8690  0.5995  0.0000  0.0000  0.0000  0.0000
# 4          4.0     4    0.8725  0.6568  0.0000  0.0000  0.0000  0.0000
# ..         ...   ...       ...     ...     ...     ...     ...     ...
# 2          NaN     2    0.7073  0.4864  0.9667  0.7250  0.8286 -0.0468
# 3          NaN     3    0.7317  0.7333  1.0000  0.7317  0.8451  0.0000
# 4          NaN     4    0.5366  0.4756  0.5862  0.7083  0.6415  0.0026
# 5          NaN  Mean    0.6732  0.5724  0.8639  0.7314  0.7864  0.0234
# 6          NaN   Std    0.0733  0.1272  0.1496  0.0157  0.0757  0.0641
#
#        MCC          target  x_data_yaer         대분류  \
# 0   0.0000   Closed_In_1Yr         2018  제조업(10~34)
# 1   0.0000   Closed_In_1Yr         2018  제조업(10~34)
# 2   0.0000   Closed_In_1Yr         2018  제조업(10~34)
# 3   0.0000   Closed_In_1Yr         2018  제조업(10~34)
# 4   0.0000   Closed_In_1Yr         2018  제조업(10~34)
# ..     ...             ...          ...         ...
# 2  -0.0957  Closed_In_2Yrs         2019  건설업(41~42)
# 3   0.0000  Closed_In_2Yrs         2019  건설업(41~42)
# 4   0.0027  Closed_In_2Yrs         2019  건설업(41~42)
# 5   0.0193  Closed_In_2Yrs         2019  건설업(41~42)
# 6   0.0862  Closed_In_2Yrs         2019  건설업(41~42)
#
#                                     feature_selection
# 0   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 1   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 2   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 3   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 4   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# ..                                                ...
# 2   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 3   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 4   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 5   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 6   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
#
# [140 rows x 13 columns]
