# %% [markdown]
# # Prerequisite
#
# Following packages must be installed to run codes below
#
# ```bash
# $ pip3 install openpyxl
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Add project path

# %%
import os
import sys
from pathlib import Path

PROJECT_PATH = Path().resolve().parent.parent
SRC_PATH = PROJECT_PATH / 'src'

sys.path.append(str(SRC_PATH))

# %%
exp_name = 'feature_selection_v3'

# %%
from project_paths import DATA_PATH
import pandas as pd

EXP_RESULT_PATH = DATA_PATH / 'experiment_result' / 'feature_selection_v2'

aggregated_result_path = EXP_RESULT_PATH / 'result.csv'

v2_exp_result = pd.read_csv(aggregated_result_path)

# %%
sectors = [
    '제조업(10~34)',
    '부동산업(68)',
    '도매 및 소매업(45~47)',
    '숙박 및 음식점업(55~56)',
    '건설업(41~42)'
]
years_to_close = [
    'Closed_In_1Yr',
    'Closed_In_2Yrs',
]

# %%
best_features = {}

for sector in sectors : 
    best_features[sector] = {}

for sector in sectors : 
    for target_years_to_close in years_to_close : 
        best_features[sector][target_years_to_close] = (
            v2_exp_result
            .loc[lambda x : x['대분류']==sector]
            .loc[lambda x : x['Fold']=='Mean']
            .loc[lambda x : x['target']==target_years_to_close]
            .set_index('feature_selection')
            ['AUC'].idxmax()
        )

# %%
from pprint import pprint
pprint(best_features)
# Out:
# {'건설업(41~42)': {'Closed_In_1Yr': "['순운전자본/자산총계', '유동부채/유동자산', '유형자산', '자본금', "
#                                  "'유보액/총자산(%)', '유보액/납입자본(%)', '차입금의존도(%)', "
#                                  "'총자본회전율(회)', '매출채권회전율(회)', '매입채무회전율(회)', "
#                                  "'Closed_In_1Yr']",
#                 'Closed_In_2Yrs': "['매출채권', '비유동자산', '유형자산', '판매비와관리비', "
#                                   "'기업순이익률(%)', '매출액총이익률(%)', '경상수지비율', "
#                                   "'차입금의존도(%)', '유동부채비율(%)', '미수금', "
#                                   "'Closed_In_2Yrs']"},
#  '도매 및 소매업(45~47)': {'Closed_In_1Yr': "['유동자산/부채총계', '순운전자본/자산총계', '유동자산', "
#                                       "'유형자산', '자산총계', '유동부채', '이익잉여금(결손금）', "
#                                       "'매출액총이익률(%)', '경상수지비율', '매입채무회전율(회)', "
#                                       "'Closed_In_1Yr']",
#                      'Closed_In_2Yrs': "['당기순이익(손실)/자산총계', '순운전자본/자산총계', "
#                                        "'매출채권', '비유동자산', '유형자산', '판매비와관리비', "
#                                        "'유보액/총자산(%)', '매출액총이익률(%)', "
#                                        "'매출액순이익률(%)', '차입금의존도(%)', "
#                                        "'Closed_In_2Yrs']"},
#  '부동산업(68)': {'Closed_In_1Yr': "['유동부채/유동자산', '비유동자산', '자산총계', '유동부채', "
#                                "'비유동부채', '이익잉여금(결손금）', '판매비와관리비', "
#                                "'유보액/총자산(%)', '경상수지비율', '부채총계대 매출액(%)', "
#                                "'Closed_In_1Yr']",
#               'Closed_In_2Yrs': "['유동부채/유동자산', '자본금', '영업이익（손실）', "
#                                 "'유보액/총자산(%)', '유보액/납입자본(%)', '경상수지비율', "
#                                 "'금융비용대부채비율(%)', '금융비용대총비용비율(%', '차입금의존도(%)', "
#                                 "'재고자산', 'Closed_In_2Yrs']"},
#  '숙박 및 음식점업(55~56)': {'Closed_In_1Yr': "['유동자산', '비유동부채', '이익잉여금(결손금）', "
#                                        "'자본총계', '법인세비용', '금융비용대부채비율(%)', "
#                                        "'차입금의존도(%)', '비유동부채비율(%)', '미수금', "
#                                        "'재고자산', 'Closed_In_1Yr']",
#                       'Closed_In_2Yrs': "['매출채권', '유형자산', '비유동부채', '자본금', "
#                                         "'판매비와관리비', '영업이익（손실）', '법인세비용차감전순손익', "
#                                         "'유보액/총자산(%)', '유보액/납입자본(%)', "
#                                         "'자기자본비율(%)', 'Closed_In_2Yrs']"},
#  '제조업(10~34)': {'Closed_In_1Yr': "['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', "
#                                  "'자본금', '법인세비용', '매출액총이익률(%)', '매출액순이익률(%)', "
#                                  "'경상수지비율', '총자본회전율(회)', 'Closed_In_1Yr']",
#                 'Closed_In_2Yrs': "['유동부채/유동자산', '유동자산', '매출채권', '유형자산', "
#                                   "'판매비와관리비', '유보액/총자산(%)', '매출액총이익률(%)', "
#                                   "'경상수지비율', '차입금의존도(%)', '재고자산', "
#                                   "'Closed_In_2Yrs']"}}

# %%
additional_features = {
    '제조업(10~34)' : [
        '3YEAR TREASURY',
        '5YEAR TREASURY',
        '10YEAR TREASURY',
        '3YEAR COPORATE BOND',
        'CD 91DAYS',
        'CALL RATE 1DAY',
        'BASE RATE',
        'DOW_JONES_COMMODITY_INDEX_PRICE',
        'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE',
        'EXCHANGE_RATE_PRICE',
        'EXCHANGE_RATE_CHANGE_RATE',
    ],
    '부동산업(68)' : [
        'NATIONWIDE',
        'CAPITAL AREA',
        'NON CAPITAL AREA'
    ],
    '도매 및 소매업(45~47)' : [
        'CSI',
        'CCI',
        'CLI'
    ],
    '숙박 및 음식점업(55~56)' : [
        'CSI',
        'CCI',
        'CLI'
    ],
    '건설업(41~42)' : [
        '3YEAR TREASURY',
        '5YEAR TREASURY',
        '10YEAR TREASURY',
        '3YEAR COPORATE BOND',
        'CD 91DAYS',
        'CALL RATE 1DAY',
        'BASE RATE',
        'DOW_JONES_COMMODITY_INDEX_PRICE',
        'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE',
        'EXCHANGE_RATE_PRICE',
        'EXCHANGE_RATE_CHANGE_RATE',
    ]
}

# %% [markdown]
# # Load data

# %%
from data_loader import SectorDataLoader

data_loader = SectorDataLoader()
data_finance = (
    data_loader
    .load_dataset()
    .pipe(data_loader.add_beaver_indicator)
    .pipe(data_loader.add_label)
)
data_finance.head()
# Out:
#          BIZ_NO CMP_PFIX_NM   CMP_NM CMP_NM1 CMP_SFIX_NM  \
# 117  1018135422         (주)   한국선박기술     NaN         NaN
# 219  1018154206         (주)     드림미즈     NaN         NaN
# 279  1018163684         NaN  디에프에스서울     NaN         (주)
# 339  1018178760         (주)    대교디앤씨     NaN         NaN
# 406  1018194173         NaN    에코에너지     NaN         (주)
#
#                        CMP_ENM BZ_TYP  CMP_TYP  CMP_SCL  PBCO_GB  ...  \
# 117  Korea Marine Time Service      M      NaN        2        2  ...
# 219         dreammiz Co., Ltd.      M      NaN        2        2  ...
# 279             DFS Seoul Ltd.      M      NaN        2        2  ...
# 339      DAEGYO D & C CO.,LTD.      M      NaN        2        2  ...
# 406        Eco Energy Co.,Ltd.      M      NaN        2        2  ...
#
#      STAT_OCR_DATE_y  Closed_Year  유동자산/부채총계 당기순이익(손실)/자산총계 부채총계/자산총계  \
# 117       20200930.0       2020.0   1.031451       0.038773  0.578094
# 219       20201231.0       2020.0   1.220040       0.001177  0.662356
# 279       20190917.0       2019.0  11.012914       0.046666  0.090794
# 339       20191010.0       2019.0   0.916364      -0.026128  1.091269
# 406       20200831.0       2020.0   1.183355      -0.062095  0.828142
#
#      순운전자본/자산총계  유동부채/유동자산  Years_From_Closed_Year_To_FS  Closed_In_1Yr  \
# 117    0.543045   0.089273                           2.0              0
# 219    0.608449   0.247063                           2.0              0
# 279    0.909114   0.090802                           1.0              1
# 339    0.097514   0.902486                           1.0              1
# 406    0.194625   0.801400                           2.0              0
#
#      Closed_In_2Yrs
# 117               1
# 219               1
# 279               1
# 339               1
# 406               1
#
# [5 rows x 104 columns]

# %%
from data_loader import IndexDataLoader
import pandas as pd
import ast

"""
index_features = [
    '3YEAR TREASURY',
    '5YEAR TREASURY',
    '10YEAR TREASURY',
    '3YEAR COPORATE BOND',
    'CD 91DAYS',
    'CALL RATE 1DAY',
    'BASE RATE',
    'YEAR_MONTH',
    'DOW_JONES_COMMODITY_INDEX_PRICE',
    'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE',
    'EXCHANGE_RATE_PRICE',
    'EXCHANGE_RATE_CHANGE_RATE',
    'NATIONWIDE',
    'CAPITAL AREA',
    'NON CAPITAL AREA',
    'CSI',
    'CCI',
    'CLI',
]
"""
index_features = [
     '3YEAR TREASURY',
     '5YEAR TREASURY',
     '10YEAR TREASURY',
     '3YEAR COPORATE BOND',
     'CD 91DAYS',
     'CALL RATE 1DAY',
     'BASE RATE',
     'YEAR_MONTH',
     'DOW_JONES_COMMODITY_INDEX_PRICE',
     'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE',
     'EXCHANGE_RATE_PRICE',
     'EXCHANGE_RATE_CHANGE_RATE',
     'NATIONWIDE',
     'CAPITAL AREA',
     'NON CAPITAL AREA',
     'CSI',
     'CCI',
     'CLI',
]

index_data_loader = IndexDataLoader()

index_data = (
    index_data_loader.load_interest_rate()
    .merge(
        (
            index_data_loader.load_dow_jones_commodity_index()
            .rename(columns={'PRICE':'DOW_JONES_COMMODITY_INDEX_PRICE',
                            'CHANGE_RATE':'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_exchange_rate()
            .rename(columns={'PRICE':'EXCHANGE_RATE_PRICE',
                            'CHANGE_RATE':'EXCHANGE_RATE_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_apartment_housing_index()
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
        
    )
    .merge(
        (
            index_data_loader.load_csi()
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .merge(
        (
            index_data_loader.load_composite_index()
            .rename(columns={'PRICE':'DOW_JONES_COMMODITY_INDEX_PRICE',
                            'CHANGE_RATE':'DOW_JONES_COMMODITY_INDEX_CHANGE_RATE'})
        ),
        how='outer',
        left_on='YEAR_MONTH',
        right_on='YEAR_MONTH'
    )
    .assign(year=lambda x : x['YEAR_MONTH'].dt.year)
    .assign(month=lambda x : x['YEAR_MONTH'].dt.month)
    .groupby(['year'])
    [index_features].mean()
    .reset_index(drop=False)
)

index_data
# Out:
#     year  3YEAR TREASURY  5YEAR TREASURY  10YEAR TREASURY  \
# 0   2006             NaN             NaN              NaN
# 1   2007             NaN             NaN              NaN
# 2   2008             NaN             NaN              NaN
# 3   2009             NaN             NaN              NaN
# 4   2010             NaN             NaN              NaN
# 5   2011             NaN             NaN              NaN
# 6   2012             NaN             NaN              NaN
# 7   2013             NaN             NaN              NaN
# 8   2014             NaN             NaN              NaN
# 9   2015             NaN             NaN              NaN
# 10  2016             NaN             NaN              NaN
# 11  2017        1.805000        2.004167         2.283333
# 12  2018        2.100833        2.308333         2.505000
# 13  2019        1.532500        1.590833         1.702500
# 14  2020        0.990000        1.235000         1.500000
# 15  2021        1.385000        1.715000         2.065833
# 16  2022             NaN             NaN              NaN
#
#     3YEAR COPORATE BOND  CD 91DAYS  CALL RATE 1DAY  BASE RATE  \
# 0                   NaN        NaN             NaN        NaN
# 1                   NaN        NaN             NaN        NaN
# 2                   NaN        NaN             NaN        NaN
# 3                   NaN        NaN             NaN        NaN
# 4                   NaN        NaN             NaN        NaN
# 5                   NaN        NaN             NaN        NaN
# 6                   NaN        NaN             NaN        NaN
# 7                   NaN        NaN             NaN        NaN
# 8                   NaN        NaN             NaN        NaN
# 9                   NaN        NaN             NaN        NaN
# 10                  NaN        NaN             NaN        NaN
# 11             2.327500   1.444167        1.260833   1.291667
# 12             2.649167   1.680000        1.521667   1.541667
# 13             2.024167   1.699167        1.591667   1.562500
# 14             2.129167   0.923333        0.698333   0.666667
# 15             2.079167   0.850000        0.612500   0.645833
# 16                  NaN        NaN             NaN        NaN
#
#     DOW_JONES_COMMODITY_INDEX_PRICE  DOW_JONES_COMMODITY_INDEX_CHANGE_RATE  \
# 0                               NaN                                    NaN
# 1                               NaN                                    NaN
# 2                               NaN                                    NaN
# 3                               NaN                                    NaN
# 4                               NaN                                    NaN
# 5                               NaN                                    NaN
# 6                               NaN                                    NaN
# 7                               NaN                                    NaN
# 8                               NaN                                    NaN
# 9                               NaN                                    NaN
# 10                              NaN                                    NaN
# 11                       580.068333                               0.830000
# 12                       625.940833                              -0.695000
# 13                       614.237500                               0.997500
# 14                       590.860000                               1.421667
# 15                       878.985000                               2.249167
# 16                              NaN                                    NaN
#
#     EXCHANGE_RATE_PRICE  EXCHANGE_RATE_CHANGE_RATE  NATIONWIDE  CAPITAL AREA  \
# 0                   NaN                        NaN   63.841667     68.600000
# 1                   NaN                        NaN   72.758333     82.441667
# 2                   NaN                        NaN   76.775000     89.150000
# 3                   NaN                        NaN   76.058333     87.833333
# 4                   NaN                        NaN   77.733333     86.833333
# 5                   NaN                        NaN   83.700000     86.850000
# 6                   NaN                        NaN   83.883333     81.891667
# 7                   NaN                        NaN   84.325000     80.333333
# 8                   NaN                        NaN   88.008333     83.366667
# 9                   NaN                        NaN   94.008333     89.175000
# 10                  NaN                        NaN   96.900000     93.716667
# 11          1121.758333                  -1.000833   99.400000     98.208333
# 12          1098.985000                   0.372500  100.608333    104.325000
# 13          1164.787500                   0.317500  100.108333    107.183333
# 14          1177.803333                  -0.499167  110.041667    122.791667
# 15          1146.869167                   0.770000  134.533333    157.608333
# 16                  NaN                        NaN  139.787500    164.037500
#
#     NON CAPITAL AREA         CSI         CCI         CLI
# 0          58.416667         NaN         NaN         NaN
# 1          60.925000         NaN         NaN         NaN
# 2          62.991667         NaN         NaN         NaN
# 3          64.200000         NaN         NaN         NaN
# 4          69.516667         NaN         NaN         NaN
# 5          80.983333         NaN         NaN         NaN
# 6          85.250000         NaN         NaN         NaN
# 7          87.125000         NaN         NaN         NaN
# 8          91.325000         NaN         NaN         NaN
# 9          97.658333         NaN         NaN         NaN
# 10         99.408333         NaN         NaN         NaN
# 11        100.333333         NaN         NaN         NaN
# 12         97.441667  104.083333  101.425000  100.058333
# 13         94.075000   99.083333  100.258333   98.475000
# 14         99.091667   88.333333   98.375000   99.033333
# 15        114.841667  103.083333   99.883333  101.150000
# 16        119.362500         NaN         NaN         NaN

# %%
data = (
    data_finance
    .assign(year=lambda x : x['결산년월'].astype(str).str[:4].astype(int))
    .merge(
        index_data,
        how='left',
        left_on='year',
        right_on='year'
    )
)
data
# Out:
#            BIZ_NO CMP_PFIX_NM          CMP_NM CMP_NM1 CMP_SFIX_NM  \
# 0      1018135422         (주)          한국선박기술     NaN         NaN
# 1      1018154206         (주)            드림미즈     NaN         NaN
# 2      1018163684         NaN         디에프에스서울     NaN         (주)
# 3      1018178760         (주)           대교디앤씨     NaN         NaN
# 4      1018194173         NaN           에코에너지     NaN         (주)
# ...           ...         ...             ...     ...         ...
# 10516  8998700283         (주)            덕성건설     NaN         NaN
# 10517  8998700283         (주)            덕성건설     NaN         NaN
# 10518  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
# 10519  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
# 10520  8998701263         NaN  하나머스트제6호기업인수목적     NaN         (주)
#
#                                                  CMP_ENM BZ_TYP  CMP_TYP  \
# 0                              Korea Marine Time Service      M      NaN
# 1                                     dreammiz Co., Ltd.      M      NaN
# 2                                         DFS Seoul Ltd.      M      NaN
# 3                                  DAEGYO D & C CO.,LTD.      M      NaN
# 4                                    Eco Energy Co.,Ltd.      M      NaN
# ...                                                  ...    ...      ...
# 10516                             Deokseong Construction      M      NaN
# 10517                             Deokseong Construction      M      NaN
# 10518  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
# 10519  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
# 10520  HANA MUST SIXTH SPECIAL PURPOSE ACQUISITION CO...      M      NaN
#
#        CMP_SCL  PBCO_GB  ...  DOW_JONES_COMMODITY_INDEX_PRICE  \
# 0            2        2  ...                       625.940833
# 1            2        2  ...                       625.940833
# 2            2        2  ...                       625.940833
# 3            2        2  ...                       625.940833
# 4            2        2  ...                       625.940833
# ...        ...      ...  ...                              ...
# 10516        2        2  ...                       625.940833
# 10517        2        2  ...                       614.237500
# 10518        2        2  ...                       625.940833
# 10519        2        2  ...                       614.237500
# 10520        2        2  ...                       590.860000
#
#        DOW_JONES_COMMODITY_INDEX_CHANGE_RATE EXCHANGE_RATE_PRICE  \
# 0                                  -0.695000         1098.985000
# 1                                  -0.695000         1098.985000
# 2                                  -0.695000         1098.985000
# 3                                  -0.695000         1098.985000
# 4                                  -0.695000         1098.985000
# ...                                      ...                 ...
# 10516                              -0.695000         1098.985000
# 10517                               0.997500         1164.787500
# 10518                              -0.695000         1098.985000
# 10519                               0.997500         1164.787500
# 10520                               1.421667         1177.803333
#
#       EXCHANGE_RATE_CHANGE_RATE  NATIONWIDE  CAPITAL AREA  NON CAPITAL AREA  \
# 0                      0.372500  100.608333    104.325000         97.441667
# 1                      0.372500  100.608333    104.325000         97.441667
# 2                      0.372500  100.608333    104.325000         97.441667
# 3                      0.372500  100.608333    104.325000         97.441667
# 4                      0.372500  100.608333    104.325000         97.441667
# ...                         ...         ...           ...               ...
# 10516                  0.372500  100.608333    104.325000         97.441667
# 10517                  0.317500  100.108333    107.183333         94.075000
# 10518                  0.372500  100.608333    104.325000         97.441667
# 10519                  0.317500  100.108333    107.183333         94.075000
# 10520                 -0.499167  110.041667    122.791667         99.091667
#
#               CSI         CCI         CLI
# 0      104.083333  101.425000  100.058333
# 1      104.083333  101.425000  100.058333
# 2      104.083333  101.425000  100.058333
# 3      104.083333  101.425000  100.058333
# 4      104.083333  101.425000  100.058333
# ...           ...         ...         ...
# 10516  104.083333  101.425000  100.058333
# 10517   99.083333  100.258333   98.475000
# 10518  104.083333  101.425000  100.058333
# 10519   99.083333  100.258333   98.475000
# 10520   88.333333   98.375000   99.033333
#
# [10521 rows x 122 columns]

# %% [markdown]
# # Baseline classifier using Beaver's features

# %%
from project_paths import DATA_PATH

sectors = [
    '제조업(10~34)',
    '부동산업(68)',
    '도매 및 소매업(45~47)',
    '숙박 및 음식점업(55~56)',
    '건설업(41~42)'
]

beaver_features = [
    '유동자산/부채총계',
    '당기순이익(손실)/자산총계',
    '부채총계/자산총계',
    '순운전자본/자산총계',
    '유동부채/유동자산'
]

extended_financial_features = [
    '유동자산',
    '매출채권',
    '비유동자산',
    '유형자산',
    '자산총계',
    '유동부채',
    '비유동부채',
    '부  채  총  계',
    '자본금',
    '이익잉여금(결손금）',
    '자본총계',
    '매출액',
    '판매비와관리비',
    '영업이익（손실）',
    '법인세비용차감전순손익',
    '법인세비용',
    '당기순이익(손실)',
    '기업순이익률(%)',
    '유보액/총자산(%)',
    '유보액/납입자본(%)',
    '매출액총이익률(%)',
    '매출액영업이익률(%)',
    '매출액순이익률(%)',
    '수지비율(%)',
    '경상수지비율',
    '영업비율(%)',
    '금융비용대매출액비율(%',
    '금융비용대부채비율(%)',
    '금융비용대총비용비율(%',
    '부채비율(%)',
    '차입금의존도(%)',
    '자기자본비율(%)',
    '순운전자본비율(%)',
    '유동부채비율(%)',
    '비유동부채비율(%)',
    '부채총계대 매출액(%)',
    '총자본회전율(회)',
    '재고자산회전율(회)',
    '매출채권회전율(회)',
    '매입채무회전율(회)',
    '미수금',
    '매출원가',
    '무형자산',
    '재고자산',
]

years_to_close = [
    'Closed_In_1Yr',
    'Closed_In_2Yrs',
]

x_data_year = list(range(2018, 2020))

EXP_RESULT_PATH = DATA_PATH / 'experiment_result' / exp_name

if not os.path.exists(EXP_RESULT_PATH) : 
    os.mkdir(EXP_RESULT_PATH)

# %%
import numpy as np
import pandas as pd
from pycaret.classification import ClassificationExperiment
from tqdm import tqdm

# %%
exp_result = None

for target_years_to_close in tqdm(years_to_close) : 
    for x_data_target_year in tqdm(x_data_year, leave=True) : 
        for sector in sectors : 

            filename = EXP_RESULT_PATH / f'Beaver_baseline_{sector}_{target_years_to_close}_{x_data_target_year}.csv'

            if not os.path.exists(filename) : 

                data_to_train = (
                    data
                    .loc[~data[beaver_features[0]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[1]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[2]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[3]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[~data[beaver_features[4]].isin([np.nan, np.inf, -np.inf]), :]
                    .loc[lambda x : pd.to_datetime(x['결산년월'], format='%Y%m%d').dt.year==x_data_target_year]
                    .loc[lambda x : x['대분류']==sector]
                )

                exp = ClassificationExperiment()

                target_features = (
                    [x for x in ast.literal_eval(best_features[sector][target_years_to_close]) if 'Closed' not in x]
                    + additional_features[sector]
                    + [target_years_to_close]
                )
                              
                exp.setup(
                    (
                        data_to_train
                        .loc[:, target_features]
                        .reset_index(drop=True)
                        .fillna(0)
                    ),
                    target=target_years_to_close,
                    #feature_selection=True,
                    #remove_multicollinearity = True,
                )

                models = exp.compare_models(sort='AUC', n_select=3)
                tuned_models = [exp.tune_model(x) for x in models]
                
                #if target_years_to_close == 'Closed_In_1Yr' :
                blended_model = exp.blend_models(estimator_list=tuned_models, fold=5, method = 'soft')
                result = (
                    exp.pull()
                    .assign(target=target_years_to_close)
                    .assign(x_data_yaer=x_data_target_year)
                    .assign(대분류=sector)
                    .reset_index(drop=False)
                    .rename(columns={'index':'model_name'})
                )
                result['feature_selection'] = str(exp.dataset_transformed.columns.tolist())
                result.to_csv(filename)

            else : 
                result = pd.read_csv(filename)

            if exp_result is None : 
                exp_result = result
            else : 
                exp_result = pd.concat([exp_result, result], axis=0)
# Out:
#   0%|                                                                                                                                                                                                                   | 0/2 [00:00<?, ?it/s]
#   0%|                                                                                                                                                                                                                   | 0/2 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9fb2c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9fb2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fb2c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9fb2c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fb2c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9fb2c_row0_col1" class="data row0 col1" >8686</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fb2c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9fb2c_row1_col1" class="data row1 col1" >Closed_In_1Yr</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fb2c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9fb2c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fb2c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9fb2c_row3_col1" class="data row3 col1" >(1800, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9fb2c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9fb2c_row4_col1" class="data row4 col1" >(1800, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9fb2c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9fb2c_row5_col1" class="data row5 col1" >(1259, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9fb2c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9fb2c_row6_col1" class="data row6 col1" >(541, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9fb2c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9fb2c_row7_col1" class="data row7 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9fb2c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9fb2c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9fb2c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9fb2c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9fb2c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9fb2c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9fb2c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9fb2c_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9fb2c_row12_col0" class="data row12 col0" >Low variance threshold</td>
#       <td id="T_9fb2c_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9fb2c_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_9fb2c_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9fb2c_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_9fb2c_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9fb2c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_9fb2c_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9fb2c_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_9fb2c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9fb2c_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_9fb2c_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9fb2c_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_9fb2c_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9fb2c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9fb2c_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_9fb2c_row19_col1" class="data row19 col1" >973d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6a75c th {
#   text-align: left;
# }
# #T_6a75c_row0_col0, #T_6a75c_row0_col1, #T_6a75c_row0_col3, #T_6a75c_row0_col4, #T_6a75c_row0_col5, #T_6a75c_row0_col6, #T_6a75c_row0_col7, #T_6a75c_row1_col0, #T_6a75c_row1_col1, #T_6a75c_row1_col2, #T_6a75c_row1_col3, #T_6a75c_row1_col4, #T_6a75c_row1_col5, #T_6a75c_row1_col6, #T_6a75c_row1_col7, #T_6a75c_row2_col0, #T_6a75c_row2_col2, #T_6a75c_row2_col3, #T_6a75c_row2_col5, #T_6a75c_row2_col6, #T_6a75c_row3_col0, #T_6a75c_row3_col1, #T_6a75c_row3_col2, #T_6a75c_row3_col3, #T_6a75c_row3_col4, #T_6a75c_row3_col5, #T_6a75c_row3_col7, #T_6a75c_row4_col0, #T_6a75c_row4_col1, #T_6a75c_row4_col2, #T_6a75c_row4_col3, #T_6a75c_row4_col4, #T_6a75c_row4_col5, #T_6a75c_row4_col6, #T_6a75c_row4_col7, #T_6a75c_row5_col0, #T_6a75c_row5_col1, #T_6a75c_row5_col2, #T_6a75c_row5_col3, #T_6a75c_row5_col4, #T_6a75c_row5_col5, #T_6a75c_row5_col6, #T_6a75c_row5_col7, #T_6a75c_row6_col0, #T_6a75c_row6_col1, #T_6a75c_row6_col2, #T_6a75c_row6_col3, #T_6a75c_row6_col4, #T_6a75c_row6_col5, #T_6a75c_row6_col6, #T_6a75c_row6_col7, #T_6a75c_row7_col0, #T_6a75c_row7_col1, #T_6a75c_row7_col2, #T_6a75c_row7_col3, #T_6a75c_row7_col4, #T_6a75c_row7_col5, #T_6a75c_row7_col6, #T_6a75c_row7_col7, #T_6a75c_row8_col0, #T_6a75c_row8_col1, #T_6a75c_row8_col2, #T_6a75c_row8_col3, #T_6a75c_row8_col4, #T_6a75c_row8_col5, #T_6a75c_row8_col6, #T_6a75c_row8_col7, #T_6a75c_row9_col0, #T_6a75c_row9_col1, #T_6a75c_row9_col2, #T_6a75c_row9_col4, #T_6a75c_row9_col6, #T_6a75c_row9_col7, #T_6a75c_row10_col0, #T_6a75c_row10_col1, #T_6a75c_row10_col2, #T_6a75c_row10_col3, #T_6a75c_row10_col4, #T_6a75c_row10_col5, #T_6a75c_row10_col6, #T_6a75c_row10_col7, #T_6a75c_row11_col0, #T_6a75c_row11_col1, #T_6a75c_row11_col2, #T_6a75c_row11_col3, #T_6a75c_row11_col4, #T_6a75c_row11_col5, #T_6a75c_row11_col6, #T_6a75c_row11_col7, #T_6a75c_row12_col0, #T_6a75c_row12_col1, #T_6a75c_row12_col2, #T_6a75c_row12_col3, #T_6a75c_row12_col4, #T_6a75c_row12_col5, #T_6a75c_row12_col6, #T_6a75c_row12_col7, #T_6a75c_row13_col0, #T_6a75c_row13_col1, #T_6a75c_row13_col2, #T_6a75c_row13_col3, #T_6a75c_row13_col4, #T_6a75c_row13_col5, #T_6a75c_row13_col6, #T_6a75c_row13_col7 {
#   text-align: left;
# }
# #T_6a75c_row0_col2, #T_6a75c_row2_col1, #T_6a75c_row2_col4, #T_6a75c_row2_col7, #T_6a75c_row3_col6, #T_6a75c_row9_col3, #T_6a75c_row9_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6a75c_row0_col8, #T_6a75c_row2_col8, #T_6a75c_row3_col8, #T_6a75c_row4_col8, #T_6a75c_row5_col8, #T_6a75c_row6_col8, #T_6a75c_row7_col8, #T_6a75c_row8_col8, #T_6a75c_row9_col8, #T_6a75c_row10_col8, #T_6a75c_row11_col8, #T_6a75c_row12_col8, #T_6a75c_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6a75c_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6a75c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a75c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a75c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6a75c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6a75c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6a75c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6a75c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6a75c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6a75c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6a75c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a75c_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_6a75c_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_6a75c_row0_col1" class="data row0 col1" >0.8713</td>
#       <td id="T_6a75c_row0_col2" class="data row0 col2" >0.6766</td>
#       <td id="T_6a75c_row0_col3" class="data row0 col3" >0.1096</td>
#       <td id="T_6a75c_row0_col4" class="data row0 col4" >0.5517</td>
#       <td id="T_6a75c_row0_col5" class="data row0 col5" >0.1778</td>
#       <td id="T_6a75c_row0_col6" class="data row0 col6" >0.1409</td>
#       <td id="T_6a75c_row0_col7" class="data row0 col7" >0.1967</td>
#       <td id="T_6a75c_row0_col8" class="data row0 col8" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_6a75c_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_6a75c_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_6a75c_row1_col1" class="data row1 col1" >0.8570</td>
#       <td id="T_6a75c_row1_col2" class="data row1 col2" >0.6442</td>
#       <td id="T_6a75c_row1_col3" class="data row1 col3" >0.1029</td>
#       <td id="T_6a75c_row1_col4" class="data row1 col4" >0.3119</td>
#       <td id="T_6a75c_row1_col5" class="data row1 col5" >0.1514</td>
#       <td id="T_6a75c_row1_col6" class="data row1 col6" >0.0996</td>
#       <td id="T_6a75c_row1_col7" class="data row1 col7" >0.1167</td>
#       <td id="T_6a75c_row1_col8" class="data row1 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_6a75c_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_6a75c_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_6a75c_row2_col1" class="data row2 col1" >0.8745</td>
#       <td id="T_6a75c_row2_col2" class="data row2 col2" >0.6431</td>
#       <td id="T_6a75c_row2_col3" class="data row2 col3" >0.1210</td>
#       <td id="T_6a75c_row2_col4" class="data row2 col4" >0.5983</td>
#       <td id="T_6a75c_row2_col5" class="data row2 col5" >0.1953</td>
#       <td id="T_6a75c_row2_col6" class="data row2 col6" >0.1597</td>
#       <td id="T_6a75c_row2_col7" class="data row2 col7" >0.2210</td>
#       <td id="T_6a75c_row2_col8" class="data row2 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_6a75c_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_6a75c_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6a75c_row3_col1" class="data row3 col1" >0.8697</td>
#       <td id="T_6a75c_row3_col2" class="data row3 col2" >0.6383</td>
#       <td id="T_6a75c_row3_col3" class="data row3 col3" >0.1397</td>
#       <td id="T_6a75c_row3_col4" class="data row3 col4" >0.4702</td>
#       <td id="T_6a75c_row3_col5" class="data row3 col5" >0.2112</td>
#       <td id="T_6a75c_row3_col6" class="data row3 col6" >0.1661</td>
#       <td id="T_6a75c_row3_col7" class="data row3 col7" >0.2027</td>
#       <td id="T_6a75c_row3_col8" class="data row3 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_6a75c_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_6a75c_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6a75c_row4_col1" class="data row4 col1" >0.8642</td>
#       <td id="T_6a75c_row4_col2" class="data row4 col2" >0.6369</td>
#       <td id="T_6a75c_row4_col3" class="data row4 col3" >0.0860</td>
#       <td id="T_6a75c_row4_col4" class="data row4 col4" >0.3650</td>
#       <td id="T_6a75c_row4_col5" class="data row4 col5" >0.1349</td>
#       <td id="T_6a75c_row4_col6" class="data row4 col6" >0.0962</td>
#       <td id="T_6a75c_row4_col7" class="data row4 col7" >0.1251</td>
#       <td id="T_6a75c_row4_col8" class="data row4 col8" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_6a75c_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_6a75c_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_6a75c_row5_col1" class="data row5 col1" >0.8649</td>
#       <td id="T_6a75c_row5_col2" class="data row5 col2" >0.6338</td>
#       <td id="T_6a75c_row5_col3" class="data row5 col3" >0.0360</td>
#       <td id="T_6a75c_row5_col4" class="data row5 col4" >0.2667</td>
#       <td id="T_6a75c_row5_col5" class="data row5 col5" >0.0622</td>
#       <td id="T_6a75c_row5_col6" class="data row5 col6" >0.0391</td>
#       <td id="T_6a75c_row5_col7" class="data row5 col7" >0.0609</td>
# <style type="text/css">
# #T_6f834_row10_col0, #T_6f834_row10_col1, #T_6f834_row10_col2, #T_6f834_row10_col3, #T_6f834_row10_col4, #T_6f834_row10_col5, #T_6f834_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6f834">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f834_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6f834_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6f834_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6f834_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6f834_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6f834_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6f834_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f834_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f834_row0_col0" class="data row0 col0" >0.8651</td>
#       <td id="T_6f834_row0_col1" class="data row0 col1" >0.4778</td>
#       <td id="T_6f834_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_6f834_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_6f834_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_6f834_row0_col5" class="data row0 col5" >-0.0152</td>
#       <td id="T_6f834_row0_col6" class="data row0 col6" >-0.0341</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f834_row1_col0" class="data row1 col0" >0.8730</td>
#       <td id="T_6f834_row1_col1" class="data row1 col1" >0.6852</td>
#       <td id="T_6f834_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_6f834_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_6f834_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_6f834_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_6f834_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f834_row2_col0" class="data row2 col0" >0.8810</td>
#       <td id="T_6f834_row2_col1" class="data row2 col1" >0.6608</td>
#       <td id="T_6f834_row2_col2" class="data row2 col2" >0.0625</td>
#       <td id="T_6f834_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_6f834_row2_col4" class="data row2 col4" >0.1176</td>
#       <td id="T_6f834_row2_col5" class="data row2 col5" >0.1043</td>
#       <td id="T_6f834_row2_col6" class="data row2 col6" >0.2345</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f834_row3_col0" class="data row3 col0" >0.8889</td>
#       <td id="T_6f834_row3_col1" class="data row3 col1" >0.7693</td>
#       <td id="T_6f834_row3_col2" class="data row3 col2" >0.1250</td>
#       <td id="T_6f834_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_6f834_row3_col4" class="data row3 col4" >0.2222</td>
#       <td id="T_6f834_row3_col5" class="data row3 col5" >0.1996</td>
#       <td id="T_6f834_row3_col6" class="data row3 col6" >0.3330</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6f834_row4_col0" class="data row4 col0" >0.8810</td>
#       <td id="T_6f834_row4_col1" class="data row4 col1" >0.6557</td>
#       <td id="T_6f834_row4_col2" class="data row4 col2" >0.0625</td>
#       <td id="T_6f834_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_6f834_row4_col4" class="data row4 col4" >0.1176</td>
#       <td id="T_6f834_row4_col5" class="data row4 col5" >0.1043</td>
#       <td id="T_6f834_row4_col6" class="data row4 col6" >0.2345</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f834_row5_col0" class="data row5 col0" >0.8810</td>
#       <td id="T_6f834_row5_col1" class="data row5 col1" >0.7620</td>
#       <td id="T_6f834_row5_col2" class="data row5 col2" >0.1176</td>
#       <td id="T_6f834_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_6f834_row5_col4" class="data row5 col4" >0.2105</td>
#       <td id="T_6f834_row5_col5" class="data row5 col5" >0.1874</td>
#       <td id="T_6f834_row5_col6" class="data row5 col6" >0.3216</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f834_row6_col0" class="data row6 col0" >0.8730</td>
#       <td id="T_6f834_row6_col1" class="data row6 col1" >0.7205</td>
#       <td id="T_6f834_row6_col2" class="data row6 col2" >0.1176</td>
#       <td id="T_6f834_row6_col3" class="data row6 col3" >0.6667</td>
#       <td id="T_6f834_row6_col4" class="data row6 col4" >0.2000</td>
#       <td id="T_6f834_row6_col5" class="data row6 col5" >0.1663</td>
#       <td id="T_6f834_row6_col6" class="data row6 col6" >0.2431</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6f834_row7_col0" class="data row7 col0" >0.8651</td>
#       <td id="T_6f834_row7_col1" class="data row7 col1" >0.6236</td>
#       <td id="T_6f834_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_6f834_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_6f834_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_6f834_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_6f834_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6f834_row8_col0" class="data row8 col0" >0.8810</td>
#       <td id="T_6f834_row8_col1" class="data row8 col1" >0.7232</td>
#       <td id="T_6f834_row8_col2" class="data row8 col2" >0.1176</td>
#       <td id="T_6f834_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_6f834_row8_col4" class="data row8 col4" >0.2105</td>
#       <td id="T_6f834_row8_col5" class="data row8 col5" >0.1874</td>
#       <td id="T_6f834_row8_col6" class="data row8 col6" >0.3216</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6f834_row9_col0" class="data row9 col0" >0.8720</td>
#       <td id="T_6f834_row9_col1" class="data row9 col1" >0.5986</td>
#       <td id="T_6f834_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_6f834_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_6f834_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_6f834_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_6f834_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6f834_row10_col0" class="data row10 col0" >0.8761</td>
#       <td id="T_6f834_row10_col1" class="data row10 col1" >0.6677</td>
#       <td id="T_6f834_row10_col2" class="data row10 col2" >0.0603</td>
#       <td id="T_6f834_row10_col3" class="data row10 col3" >0.5667</td>
#       <td id="T_6f834_row10_col4" class="data row10 col4" >0.1079</td>
#       <td id="T_6f834_row10_col5" class="data row10 col5" >0.0934</td>
#       <td id="T_6f834_row10_col6" class="data row10 col6" >0.1654</td>
#     </tr>
#     <tr>
#       <th id="T_6f834_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6f834_row11_col0" class="data row11 col0" >0.0073</td>
#       <td id="T_6f834_row11_col1" class="data row11 col1" >0.0827</td>
#       <td id="T_6f834_row11_col2" class="data row11 col2" >0.0535</td>
#       <td id="T_6f834_row11_col3" class="data row11 col3" >0.4726</td>
#       <td id="T_6f834_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_e8653_row10_col0, #T_e8653_row10_col1, #T_e8653_row10_col2, #T_e8653_row10_col3, #T_e8653_row10_col4, #T_e8653_row10_col5, #T_e8653_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e8653">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8653_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e8653_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e8653_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e8653_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e8653_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e8653_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e8653_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8653_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8653_row0_col0" class="data row0 col0" >0.8571</td>
#       <td id="T_e8653_row0_col1" class="data row0 col1" >0.4682</td>
#       <td id="T_e8653_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_e8653_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_e8653_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_e8653_row0_col5" class="data row0 col5" >-0.0290</td>
#       <td id="T_e8653_row0_col6" class="data row0 col6" >-0.0484</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8653_row1_col0" class="data row1 col0" >0.8730</td>
#       <td id="T_e8653_row1_col1" class="data row1 col1" >0.6330</td>
#       <td id="T_e8653_row1_col2" class="data row1 col2" >0.1875</td>
#       <td id="T_e8653_row1_col3" class="data row1 col3" >0.5000</td>
#       <td id="T_e8653_row1_col4" class="data row1 col4" >0.2727</td>
#       <td id="T_e8653_row1_col5" class="data row1 col5" >0.2186</td>
#       <td id="T_e8653_row1_col6" class="data row1 col6" >0.2505</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8653_row2_col0" class="data row2 col0" >0.8730</td>
#       <td id="T_e8653_row2_col1" class="data row2 col1" >0.7199</td>
#       <td id="T_e8653_row2_col2" class="data row2 col2" >0.0625</td>
#       <td id="T_e8653_row2_col3" class="data row2 col3" >0.5000</td>
#       <td id="T_e8653_row2_col4" class="data row2 col4" >0.1111</td>
#       <td id="T_e8653_row2_col5" class="data row2 col5" >0.0853</td>
#       <td id="T_e8653_row2_col6" class="data row2 col6" >0.1423</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8653_row3_col0" class="data row3 col0" >0.8651</td>
#       <td id="T_e8653_row3_col1" class="data row3 col1" >0.6403</td>
#       <td id="T_e8653_row3_col2" class="data row3 col2" >0.0625</td>
#       <td id="T_e8653_row3_col3" class="data row3 col3" >0.3333</td>
#       <td id="T_e8653_row3_col4" class="data row3 col4" >0.1053</td>
#       <td id="T_e8653_row3_col5" class="data row3 col5" >0.0679</td>
#       <td id="T_e8653_row3_col6" class="data row3 col6" >0.0968</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8653_row4_col0" class="data row4 col0" >0.8730</td>
#       <td id="T_e8653_row4_col1" class="data row4 col1" >0.5994</td>
#       <td id="T_e8653_row4_col2" class="data row4 col2" >0.0625</td>
#       <td id="T_e8653_row4_col3" class="data row4 col3" >0.5000</td>
#       <td id="T_e8653_row4_col4" class="data row4 col4" >0.1111</td>
#       <td id="T_e8653_row4_col5" class="data row4 col5" >0.0853</td>
#       <td id="T_e8653_row4_col6" class="data row4 col6" >0.1423</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8653_row5_col0" class="data row5 col0" >0.8730</td>
#       <td id="T_e8653_row5_col1" class="data row5 col1" >0.7366</td>
#       <td id="T_e8653_row5_col2" class="data row5 col2" >0.1765</td>
#       <td id="T_e8653_row5_col3" class="data row5 col3" >0.6000</td>
#       <td id="T_e8653_row5_col4" class="data row5 col4" >0.2727</td>
#       <td id="T_e8653_row5_col5" class="data row5 col5" >0.2252</td>
#       <td id="T_e8653_row5_col6" class="data row5 col6" >0.2767</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8653_row6_col0" class="data row6 col0" >0.8333</td>
#       <td id="T_e8653_row6_col1" class="data row6 col1" >0.7507</td>
#       <td id="T_e8653_row6_col2" class="data row6 col2" >0.0588</td>
#       <td id="T_e8653_row6_col3" class="data row6 col3" >0.1667</td>
#       <td id="T_e8653_row6_col4" class="data row6 col4" >0.0870</td>
#       <td id="T_e8653_row6_col5" class="data row6 col5" >0.0178</td>
#       <td id="T_e8653_row6_col6" class="data row6 col6" >0.0208</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8653_row7_col0" class="data row7 col0" >0.8810</td>
#       <td id="T_e8653_row7_col1" class="data row7 col1" >0.6317</td>
#       <td id="T_e8653_row7_col2" class="data row7 col2" >0.1765</td>
#       <td id="T_e8653_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_e8653_row7_col4" class="data row7 col4" >0.2857</td>
#       <td id="T_e8653_row7_col5" class="data row7 col5" >0.2470</td>
#       <td id="T_e8653_row7_col6" class="data row7 col6" >0.3260</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8653_row8_col0" class="data row8 col0" >0.8492</td>
#       <td id="T_e8653_row8_col1" class="data row8 col1" >0.6352</td>
#       <td id="T_e8653_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_e8653_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_e8653_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_e8653_row8_col5" class="data row8 col5" >-0.0292</td>
#       <td id="T_e8653_row8_col6" class="data row8 col6" >-0.0502</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8653_row9_col0" class="data row9 col0" >0.8480</td>
#       <td id="T_e8653_row9_col1" class="data row9 col1" >0.6365</td>
#       <td id="T_e8653_row9_col2" class="data row9 col2" >0.0625</td>
#       <td id="T_e8653_row9_col3" class="data row9 col3" >0.2000</td>
#       <td id="T_e8653_row9_col4" class="data row9 col4" >0.0952</td>
#       <td id="T_e8653_row9_col5" class="data row9 col5" >0.0365</td>
#       <td id="T_e8653_row9_col6" class="data row9 col6" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e8653_row10_col0" class="data row10 col0" >0.8626</td>
#       <td id="T_e8653_row10_col1" class="data row10 col1" >0.6451</td>
#       <td id="T_e8653_row10_col2" class="data row10 col2" >0.0849</td>
#       <td id="T_e8653_row10_col3" class="data row10 col3" >0.3550</td>
#       <td id="T_e8653_row10_col4" class="data row10 col4" >0.1341</td>
#       <td id="T_e8653_row10_col5" class="data row10 col5" >0.0925</td>
#       <td id="T_e8653_row10_col6" class="data row10 col6" >0.1201</td>
#     </tr>
#     <tr>
#       <th id="T_e8653_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e8653_row11_col0" class="data row11 col0" >0.0143</td>
#       <td id="T_e8653_row11_col1" class="data row11 col1" >0.0768</td>
#       <td id="T_e8653_row11_col2" class="data row11 col2" >0.0666</td>
#       <td id="T_e8653_row11_col3" class="data row11 col3" >0.2431</td>
#       <td id="T_e8653_row11_
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_39cad_row10_col0, #T_39cad_row10_col1, #T_39cad_row10_col2, #T_39cad_row10_col3, #T_39cad_row10_col4, #T_39cad_row10_col5, #T_39cad_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_39cad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39cad_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_39cad_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_39cad_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_39cad_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_39cad_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_39cad_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_39cad_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39cad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39cad_row0_col0" class="data row0 col0" >0.8730</td>
#       <td id="T_39cad_row0_col1" class="data row0 col1" >0.4520</td>
#       <td id="T_39cad_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_39cad_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_39cad_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_39cad_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_39cad_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39cad_row1_col0" class="data row1 col0" >0.8730</td>
#       <td id="T_39cad_row1_col1" class="data row1 col1" >0.6497</td>
#       <td id="T_39cad_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_39cad_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_39cad_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_39cad_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_39cad_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39cad_row2_col0" class="data row2 col0" >0.8730</td>
#       <td id="T_39cad_row2_col1" class="data row2 col1" >0.7267</td>
#       <td id="T_39cad_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_39cad_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_39cad_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_39cad_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_39cad_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39cad_row3_col0" class="data row3 col0" >0.8730</td>
#       <td id="T_39cad_row3_col1" class="data row3 col1" >0.5980</td>
#       <td id="T_39cad_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_39cad_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_39cad_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_39cad_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_39cad_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39cad_row4_col0" class="data row4 col0" >0.8730</td>
#       <td id="T_39cad_row4_col1" class="data row4 col1" >0.6000</td>
#       <td id="T_39cad_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_39cad_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_39cad_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_39cad_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_39cad_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_39cad_row5_col0" class="data row5 col0" >0.8651</td>
#       <td id="T_39cad_row5_col1" class="data row5 col1" >0.7310</td>
#       <td id="T_39cad_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_39cad_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_39cad_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_39cad_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_39cad_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_39cad_row6_col0" class="data row6 col0" >0.8651</td>
#       <td id="T_39cad_row6_col1" class="data row6 col1" >0.7358</td>
#       <td id="T_39cad_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_39cad_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_39cad_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_39cad_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_39cad_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_39cad_row7_col0" class="data row7 col0" >0.8651</td>
#       <td id="T_39cad_row7_col1" class="data row7 col1" >0.6538</td>
#       <td id="T_39cad_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_39cad_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_39cad_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_39cad_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_39cad_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_39cad_row8_col0" class="data row8 col0" >0.8651</td>
#       <td id="T_39cad_row8_col1" class="data row8 col1" >0.6363</td>
#       <td id="T_39cad_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_39cad_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_39cad_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_39cad_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_39cad_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_39cad_row9_col0" class="data row9 col0" >0.8720</td>
#       <td id="T_39cad_row9_col1" class="data row9 col1" >0.6585</td>
#       <td id="T_39cad_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_39cad_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_39cad_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_39cad_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_39cad_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_39cad_row10_col0" class="data row10 col0" >0.8697</td>
#       <td id="T_39cad_row10_col1" class="data row10 col1" >0.6442</td>
#       <td id="T_39cad_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_39cad_row10_col3" class="data row10 col3" >0.0000</td>
#       <td id="T_39cad_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_39cad_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_39cad_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_39cad_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_39cad_row11_col0" class="data row11 col0" >0.0038</td>
#       <td id="T_39cad_row11_col1" class="data row11 col1" >0.0801</td>
#       <td id="T_39cad_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_39cad_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_39cad_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_ba9cd_row5_col0, #T_ba9cd_row5_col1, #T_ba9cd_row5_col2, #T_ba9cd_row5_col3, #T_ba9cd_row5_col4, #T_ba9cd_row5_col5, #T_ba9cd_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ba9cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba9cd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ba9cd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ba9cd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ba9cd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ba9cd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ba9cd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ba9cd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba9cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba9cd_row0_col0" class="data row0 col0" >0.8294</td>
#       <td id="T_ba9cd_row0_col1" class="data row0 col1" >0.5741</td>
#       <td id="T_ba9cd_row0_col2" class="data row0 col2" >0.1212</td>
#       <td id="T_ba9cd_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_ba9cd_row0_col4" class="data row0 col4" >0.1569</td>
#       <td id="T_ba9cd_row0_col5" class="data row0 col5" >0.0710</td>
#       <td id="T_ba9cd_row0_col6" class="data row0 col6" >0.0750</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba9cd_row1_col0" class="data row1 col0" >0.8810</td>
#       <td id="T_ba9cd_row1_col1" class="data row1 col1" >0.6657</td>
#       <td id="T_ba9cd_row1_col2" class="data row1 col2" >0.1515</td>
#       <td id="T_ba9cd_row1_col3" class="data row1 col3" >0.7143</td>
#       <td id="T_ba9cd_row1_col4" class="data row1 col4" >0.2500</td>
#       <td id="T_ba9cd_row1_col5" class="data row1 col5" >0.2140</td>
#       <td id="T_ba9cd_row1_col6" class="data row1 col6" >0.2923</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba9cd_row2_col0" class="data row2 col0" >0.8889</td>
#       <td id="T_ba9cd_row2_col1" class="data row2 col1" >0.7109</td>
#       <td id="T_ba9cd_row2_col2" class="data row2 col2" >0.1515</td>
#       <td id="T_ba9cd_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_ba9cd_row2_col4" class="data row2 col4" >0.2632</td>
#       <td id="T_ba9cd_row2_col5" class="data row2 col5" >0.2369</td>
#       <td id="T_ba9cd_row2_col6" class="data row2 col6" >0.3665</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba9cd_row3_col0" class="data row3 col0" >0.8849</td>
#       <td id="T_ba9cd_row3_col1" class="data row3 col1" >0.6781</td>
#       <td id="T_ba9cd_row3_col2" class="data row3 col2" >0.1515</td>
#       <td id="T_ba9cd_row3_col3" class="data row3 col3" >0.8333</td>
#       <td id="T_ba9cd_row3_col4" class="data row3 col4" >0.2564</td>
#       <td id="T_ba9cd_row3_col5" class="data row3 col5" >0.2252</td>
#       <td id="T_ba9cd_row3_col6" class="data row3 col6" >0.3252</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba9cd_row4_col0" class="data row4 col0" >0.8645</td>
#       <td id="T_ba9cd_row4_col1" class="data row4 col1" >0.6511</td>
#       <td id="T_ba9cd_row4_col2" class="data row4 col2" >0.0625</td>
#       <td id="T_ba9cd_row4_col3" class="data row4 col3" >0.3333</td>
#       <td id="T_ba9cd_row4_col4" class="data row4 col4" >0.1053</td>
#       <td id="T_ba9cd_row4_col5" class="data row4 col5" >0.0677</td>
#       <td id="T_ba9cd_row4_col6" class="data row4 col6" >0.0966</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ba9cd_row5_col0" class="data row5 col0" >0.8697</td>
#       <td id="T_ba9cd_row5_col1" class="data row5 col1" >0.6560</td>
#       <td id="T_ba9cd_row5_col2" class="data row5 col2" >0.1277</td>
#       <td id="T_ba9cd_row5_col3" class="data row5 col3" >0.6206</td>
#       <td id="T_ba9cd_row5_col4" class="data row5 col4" >0.2063</td>
#       <td id="T_ba9cd_row5_col5" class="data row5 col5" >0.1629</td>
#       <td id="T_ba9cd_row5_col6" class="data row5 col6" >0.2311</td>
#     </tr>
#     <tr>
#       <th id="T_ba9cd_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_ba9cd_row6_col0" class="data row6 col0" >0.0218</td>
#       <td id="T_ba9cd_row6_col1" class="data row6 col1" >0.0455</td>
#       <td id="T_ba9cd_row6_col2" class="data row6 col2" >0.0346</td>
#       <td id="T_ba9cd_row6_col3" class="data row6 col3" >0.2964</td>
#       <td id="T_ba9cd_row6_col4" class="data row6 col4" >0.0637</td>
#       <td id="T_ba9cd_row6_col5" class="data row6 col5" >0.0768</td>
#       <td id="T_ba9cd_row6_col6" class="data row6 col6" >0.1211</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f8999_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8999">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8999_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8999_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8999_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8999_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8999_row0_col1" class="data row0 col1" >4096</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8999_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8999_row1_col1" class="data row1 col1" >Closed_In_1Yr</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8999_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f8999_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8999_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f8999_row3_col1" class="data row3 col1" >(323, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8999_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f8999_row4_col1" class="data row4 col1" >(323, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8999_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f8999_row5_col1" class="data row5 col1" >(226, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8999_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f8999_row6_col1" class="data row6 col1" >(97, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f8999_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f8999_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f8999_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f8999_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f8999_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f8999_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f8999_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f8999_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f8999_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f8999_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f8999_row12_col0" class="data row12 col0" >Low variance threshold</td>
#       <td id="T_f8999_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f8999_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_f8999_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f8999_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_f8999_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f8999_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_f8999_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f8999_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f8999_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_f8999_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
# ...
#       <td id="T_b0d86_row8_col2" class="data row8 col2" >0.9333</td>
#       <td id="T_b0d86_row8_col3" class="data row8 col3" >0.8750</td>
#       <td id="T_b0d86_row8_col4" class="data row8 col4" >0.9032</td>
#       <td id="T_b0d86_row8_col5" class="data row8 col5" >0.5714</td>
#       <td id="T_b0d86_row8_col6" class="data row8 col6" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_b0d86_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b0d86_row9_col0" class="data row9 col0" >0.6000</td>
#       <td id="T_b0d86_row9_col1" class="data row9 col1" >0.7024</td>
#       <td id="T_b0d86_row9_col2" class="data row9 col2" >0.7143</td>
#       <td id="T_b0d86_row9_col3" class="data row9 col3" >0.7143</td>
#       <td id="T_b0d86_row9_col4" class="data row9 col4" >0.7143</td>
#       <td id="T_b0d86_row9_col5" class="data row9 col5" >0.0476</td>
#       <td id="T_b0d86_row9_col6" class="data row9 col6" >0.0476</td>
#     </tr>
#     <tr>
#       <th id="T_b0d86_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b0d86_row10_col0" class="data row10 col0" >0.7414</td>
#       <td id="T_b0d86_row10_col1" class="data row10 col1" >0.6863</td>
#       <td id="T_b0d86_row10_col2" class="data row10 col2" >0.8714</td>
#       <td id="T_b0d86_row10_col3" class="data row10 col3" >0.7930</td>
#       <td id="T_b0d86_row10_col4" class="data row10 col4" >0.8278</td>
#       <td id="T_b0d86_row10_col5" class="data row10 col5" >0.2960</td>
#       <td id="T_b0d86_row10_col6" class="data row10 col6" >0.3222</td>
#     </tr>
#     <tr>
#       <th id="T_b0d86_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b0d86_row11_col0" class="data row11 col0" >0.0730</td>
#       <td id="T_b0d86_row11_col1" class="data row11 col1" >0.0619</td>
#       <td id="T_b0d86_row11_col2" class="data row11 col2" >0.0993</td>
#       <td id="T_b0d86_row11_col3" class="data row11 col3" >0.0443</td>
#       <td id="T_b0d86_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_67b79_row10_col0, #T_67b79_row10_col1, #T_67b79_row10_col2, #T_67b79_row10_col3, #T_67b79_row10_col4, #T_67b79_row10_col5, #T_67b79_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_67b79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67b79_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_67b79_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_67b79_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_67b79_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_67b79_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_67b79_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_67b79_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67b79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67b79_row0_col0" class="data row0 col0" >0.8571</td>
#       <td id="T_67b79_row0_col1" class="data row0 col1" >0.8556</td>
#       <td id="T_67b79_row0_col2" class="data row0 col2" >0.8667</td>
#       <td id="T_67b79_row0_col3" class="data row0 col3" >0.9286</td>
#       <td id="T_67b79_row0_col4" class="data row0 col4" >0.8966</td>
#       <td id="T_67b79_row0_col5" class="data row0 col5" >0.6667</td>
#       <td id="T_67b79_row0_col6" class="data row0 col6" >0.6708</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67b79_row1_col0" class="data row1 col0" >0.5714</td>
#       <td id="T_67b79_row1_col1" class="data row1 col1" >0.6667</td>
#       <td id="T_67b79_row1_col2" class="data row1 col2" >0.6000</td>
#       <td id="T_67b79_row1_col3" class="data row1 col3" >0.7500</td>
#       <td id="T_67b79_row1_col4" class="data row1 col4" >0.6667</td>
#       <td id="T_67b79_row1_col5" class="data row1 col5" >0.0870</td>
#       <td id="T_67b79_row1_col6" class="data row1 col6" >0.0913</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67b79_row2_col0" class="data row2 col0" >0.6667</td>
#       <td id="T_67b79_row2_col1" class="data row2 col1" >0.7111</td>
#       <td id="T_67b79_row2_col2" class="data row2 col2" >0.6667</td>
#       <td id="T_67b79_row2_col3" class="data row2 col3" >0.8333</td>
#       <td id="T_67b79_row2_col4" class="data row2 col4" >0.7407</td>
#       <td id="T_67b79_row2_col5" class="data row2 col5" >0.2899</td>
#       <td id="T_67b79_row2_col6" class="data row2 col6" >0.3043</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_67b79_row3_col0" class="data row3 col0" >0.8095</td>
#       <td id="T_67b79_row3_col1" class="data row3 col1" >0.8222</td>
#       <td id="T_67b79_row3_col2" class="data row3 col2" >0.8667</td>
#       <td id="T_67b79_row3_col3" class="data row3 col3" >0.8667</td>
#       <td id="T_67b79_row3_col4" class="data row3 col4" >0.8667</td>
#       <td id="T_67b79_row3_col5" class="data row3 col5" >0.5333</td>
#       <td id="T_67b79_row3_col6" class="data row3 col6" >0.5333</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_67b79_row4_col0" class="data row4 col0" >0.7619</td>
#       <td id="T_67b79_row4_col1" class="data row4 col1" >0.6667</td>
#       <td id="T_67b79_row4_col2" class="data row4 col2" >0.8667</td>
#       <td id="T_67b79_row4_col3" class="data row4 col3" >0.8125</td>
#       <td id="T_67b79_row4_col4" class="data row4 col4" >0.8387</td>
#       <td id="T_67b79_row4_col5" class="data row4 col5" >0.3860</td>
#       <td id="T_67b79_row4_col6" class="data row4 col6" >0.3889</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_67b79_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_67b79_row5_col1" class="data row5 col1" >0.8000</td>
#       <td id="T_67b79_row5_col2" class="data row5 col2" >0.9333</td>
#       <td id="T_67b79_row5_col3" class="data row5 col3" >0.9333</td>
#       <td id="T_67b79_row5_col4" class="data row5 col4" >0.9333</td>
#       <td id="T_67b79_row5_col5" class="data row5 col5" >0.7333</td>
#       <td id="T_67b79_row5_col6" class="data row5 col6" >0.7333</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_67b79_row6_col0" class="data row6 col0" >0.7000</td>
#       <td id="T_67b79_row6_col1" class="data row6 col1" >0.6267</td>
#       <td id="T_67b79_row6_col2" class="data row6 col2" >0.7333</td>
#       <td id="T_67b79_row6_col3" class="data row6 col3" >0.8462</td>
#       <td id="T_67b79_row6_col4" class="data row6 col4" >0.7857</td>
#       <td id="T_67b79_row6_col5" class="data row6 col5" >0.2941</td>
#       <td id="T_67b79_row6_col6" class="data row6 col6" >0.3026</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_67b79_row7_col0" class="data row7 col0" >0.6000</td>
#       <td id="T_67b79_row7_col1" class="data row7 col1" >0.5200</td>
#       <td id="T_67b79_row7_col2" class="data row7 col2" >0.7333</td>
#       <td id="T_67b79_row7_col3" class="data row7 col3" >0.7333</td>
#       <td id="T_67b79_row7_col4" class="data row7 col4" >0.7333</td>
#       <td id="T_67b79_row7_col5" class="data row7 col5" >-0.0667</td>
#       <td id="T_67b79_row7_col6" class="data row7 col6" >-0.0667</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_67b79_row8_col0" class="data row8 col0" >0.7500</td>
#       <td id="T_67b79_row8_col1" class="data row8 col1" >0.6800</td>
#       <td id="T_67b79_row8_col2" class="data row8 col2" >0.8667</td>
#       <td id="T_67b79_row8_col3" class="data row8 col3" >0.8125</td>
#       <td id="T_67b79_row8_col4" class="data row8 col4" >0.8387</td>
#       <td id="T_67b79_row8_col5" class="data row8 col5" >0.2857</td>
#       <td id="T_67b79_row8_col6" class="data row8 col6" >0.2887</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_67b79_row9_col0" class="data row9 col0" >0.7000</td>
#       <td id="T_67b79_row9_col1" class="data row9 col1" >0.7024</td>
#       <td id="T_67b79_row9_col2" class="data row9 col2" >0.7857</td>
#       <td id="T_67b79_row9_col3" class="data row9 col3" >0.7857</td>
#       <td id="T_67b79_row9_col4" class="data row9 col4" >0.7857</td>
#       <td id="T_67b79_row9_col5" class="data row9 col5" >0.2857</td>
#       <td id="T_67b79_row9_col6" class="data row9 col6" >0.2857</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_67b79_row10_col0" class="data row10 col0" >0.7317</td>
#       <td id="T_67b79_row10_col1" class="data row10 col1" >0.7051</td>
#       <td id="T_67b79_row10_col2" class="data row10 col2" >0.7919</td>
#       <td id="T_67b79_row10_col3" class="data row10 col3" >0.8302</td>
#       <td id="T_67b79_row10_col4" class="data row10 col4" >0.8086</td>
#       <td id="T_67b79_row10_col5" class="data row10 col5" >0.3495</td>
#       <td id="T_67b79_row10_col6" class="data row10 col6" >0.3532</td>
#     </tr>
#     <tr>
#       <th id="T_67b79_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_67b79_row11_col0" class="data row11 col0" >0.1003</td>
#       <td id="T_67b79_row11_col1" class="data row11 col1" >0.0946</td>
#       <td id="T_67b79_row11_col2" class="data row11 col2" >0.1009</td>
#       <td id="T_67b79_row11_col3" class="data row11 col3" >0.0635</td>
#       <td id="T_67b79_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_ad1bb_row5_col0, #T_ad1bb_row5_col1, #T_ad1bb_row5_col2, #T_ad1bb_row5_col3, #T_ad1bb_row5_col4, #T_ad1bb_row5_col5, #T_ad1bb_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ad1bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad1bb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ad1bb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ad1bb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ad1bb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ad1bb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ad1bb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ad1bb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad1bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad1bb_row0_col0" class="data row0 col0" >0.7561</td>
#       <td id="T_ad1bb_row0_col1" class="data row0 col1" >0.7061</td>
#       <td id="T_ad1bb_row0_col2" class="data row0 col2" >0.9000</td>
#       <td id="T_ad1bb_row0_col3" class="data row0 col3" >0.7941</td>
#       <td id="T_ad1bb_row0_col4" class="data row0 col4" >0.8438</td>
#       <td id="T_ad1bb_row0_col5" class="data row0 col5" >0.2979</td>
#       <td id="T_ad1bb_row0_col6" class="data row0 col6" >0.3104</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad1bb_row1_col0" class="data row1 col0" >0.7805</td>
#       <td id="T_ad1bb_row1_col1" class="data row1 col1" >0.7333</td>
#       <td id="T_ad1bb_row1_col2" class="data row1 col2" >0.8667</td>
#       <td id="T_ad1bb_row1_col3" class="data row1 col3" >0.8387</td>
#       <td id="T_ad1bb_row1_col4" class="data row1 col4" >0.8525</td>
#       <td id="T_ad1bb_row1_col5" class="data row1 col5" >0.4243</td>
#       <td id="T_ad1bb_row1_col6" class="data row1 col6" >0.4252</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad1bb_row2_col0" class="data row2 col0" >0.7561</td>
#       <td id="T_ad1bb_row2_col1" class="data row2 col1" >0.8424</td>
#       <td id="T_ad1bb_row2_col2" class="data row2 col2" >0.9667</td>
#       <td id="T_ad1bb_row2_col3" class="data row2 col3" >0.7632</td>
#       <td id="T_ad1bb_row2_col4" class="data row2 col4" >0.8529</td>
#       <td id="T_ad1bb_row2_col5" class="data row2 col5" >0.1929</td>
#       <td id="T_ad1bb_row2_col6" class="data row2 col6" >0.2526</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad1bb_row3_col0" class="data row3 col0" >0.7073</td>
#       <td id="T_ad1bb_row3_col1" class="data row3 col1" >0.6455</td>
#       <td id="T_ad1bb_row3_col2" class="data row3 col2" >0.8667</td>
#       <td id="T_ad1bb_row3_col3" class="data row3 col3" >0.7647</td>
#       <td id="T_ad1bb_row3_col4" class="data row3 col4" >0.8125</td>
#       <td id="T_ad1bb_row3_col5" class="data row3 col5" >0.1575</td>
#       <td id="T_ad1bb_row3_col6" class="data row3 col6" >0.1641</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad1bb_row4_col0" class="data row4 col0" >0.7805</td>
#       <td id="T_ad1bb_row4_col1" class="data row4 col1" >0.7356</td>
#       <td id="T_ad1bb_row4_col2" class="data row4 col2" >0.8621</td>
#       <td id="T_ad1bb_row4_col3" class="data row4 col3" >0.8333</td>
#       <td id="T_ad1bb_row4_col4" class="data row4 col4" >0.8475</td>
#       <td id="T_ad1bb_row4_col5" class="data row4 col5" >0.4566</td>
#       <td id="T_ad1bb_row4_col6" class="data row4 col6" >0.4574</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_ad1bb_row5_col0" class="data row5 col0" >0.7561</td>
#       <td id="T_ad1bb_row5_col1" class="data row5 col1" >0.7326</td>
#       <td id="T_ad1bb_row5_col2" class="data row5 col2" >0.8924</td>
#       <td id="T_ad1bb_row5_col3" class="data row5 col3" >0.7988</td>
#       <td id="T_ad1bb_row5_col4" class="data row5 col4" >0.8418</td>
#       <td id="T_ad1bb_row5_col5" class="data row5 col5" >0.3059</td>
#       <td id="T_ad1bb_row5_col6" class="data row5 col6" >0.3220</td>
#     </tr>
#     <tr>
#       <th id="T_ad1bb_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_ad1bb_row6_col0" class="data row6 col0" >0.0267</td>
#       <td id="T_ad1bb_row6_col1" class="data row6 col1" >0.0638</td>
#       <td id="T_ad1bb_row6_col2" class="data row6 col2" >0.0395</td>
#       <td id="T_ad1bb_row6_col3" class="data row6 col3" >0.0324</td>
#       <td id="T_ad1bb_row6_col4" class="data row6 col4" >0.0150</td>
#       <td id="T_ad1bb_row6_col5" class="data row6 col5" >0.1196</td>
#       <td id="T_ad1bb_row6_col6" class="data row6 col6" >0.1085</td>
#     </tr>
#   </tbody>
# </table>
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [03:17<00:00, 98.57s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [06:29<00:00, 194.69s/it]

# %%
aggregated_result_path = EXP_RESULT_PATH / 'result.csv'

if not os.path.exists(aggregated_result_path) :
    exp_result.to_csv(aggregated_result_path)
    
exp_result
# Out:
#     Fold  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  \
# 0      0    0.8294  0.5741  0.1212  0.2222  0.1569  0.0710  0.0750
# 1      1    0.8810  0.6657  0.1515  0.7143  0.2500  0.2140  0.2923
# 2      2    0.8889  0.7109  0.1515  1.0000  0.2632  0.2369  0.3665
# 3      3    0.8849  0.6781  0.1515  0.8333  0.2564  0.2252  0.3252
# 4      4    0.8645  0.6511  0.0625  0.3333  0.1053  0.0677  0.0966
# ..   ...       ...     ...     ...     ...     ...     ...     ...
# 2      2    0.7561  0.8424  0.9667  0.7632  0.8529  0.1929  0.2526
# 3      3    0.7073  0.6455  0.8667  0.7647  0.8125  0.1575  0.1641
# 4      4    0.7805  0.7356  0.8621  0.8333  0.8475  0.4566  0.4574
# 5   Mean    0.7561  0.7326  0.8924  0.7988  0.8418  0.3059  0.3220
# 6    Std    0.0267  0.0638  0.0395  0.0324  0.0150  0.1196  0.1085
#
#             target  x_data_yaer         대분류  \
# 0    Closed_In_1Yr         2018  제조업(10~34)
# 1    Closed_In_1Yr         2018  제조업(10~34)
# 2    Closed_In_1Yr         2018  제조업(10~34)
# 3    Closed_In_1Yr         2018  제조업(10~34)
# 4    Closed_In_1Yr         2018  제조업(10~34)
# ..             ...          ...         ...
# 2   Closed_In_2Yrs         2019  건설업(41~42)
# 3   Closed_In_2Yrs         2019  건설업(41~42)
# 4   Closed_In_2Yrs         2019  건설업(41~42)
# 5   Closed_In_2Yrs         2019  건설업(41~42)
# 6   Closed_In_2Yrs         2019  건설업(41~42)
#
#                                     feature_selection
# 0   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 1   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 2   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 3   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# 4   ['순운전자본/자산총계', '매출채권', '비유동자산', '유형자산', '자본금',...
# ..                                                ...
# 2   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 3   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 4   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 5   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
# 6   ['매출채권', '비유동자산', '유형자산', '판매비와관리비', '기업순이익률(%...
#
# [140 rows x 12 columns]
